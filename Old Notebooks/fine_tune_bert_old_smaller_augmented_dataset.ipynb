# %% [markdown]
# https://colab.research.google.com/github/NadirEM/nlp-notebooks/blob/master/Fine_tune_ALBERT_sentence_pair_classification.ipynb#scrollTo=xtkcmIY9t6AF

# %% [markdown]
# ## Installation of libraries and imports

# %%
# !pip install transformers
# !pip install datasets
# Out:
# Collecting transformers
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 8.6 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 45.0 MB/s
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.5.1-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 7.1 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 55.6 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      |████████████████████████████████| 880 kB 53.8 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=575daf67ee30685b3d1781e2c431cf5501f8a48ed18233bda3994585c03fae2c
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built sacremoses
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.5.1 pyyaml-6.0 sacremoses-0.0.53 tokenizers-0.12.1 transformers-4.18.0
# Collecting datasets
#   Downloading datasets-2.1.0-py3-none-any.whl (325 kB)
#      |████████████████████████████████| 325 kB 30.0 MB/s
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.12.2)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.5.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 57.3 MB/s
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 58.8 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.6)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.11.3)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Collecting fsspec[http]>=2021.05.0
#   Downloading fsspec-2022.3.0-py3-none-any.whl (136 kB)
#      |████████████████████████████████| 136 kB 71.8 MB/s
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.64.0)
# Requirement already satisfied: pyarrow>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (4.2.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 75.5 MB/s
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (21.4.0)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 61.7 MB/s
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 68.4 MB/s
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.0.12)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 4.1 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.8.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: multidict, frozenlist, yarl, urllib3, asynctest, async-timeout, aiosignal, fsspec, aiohttp, xxhash, responses, datasets
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 asynctest-0.13.0 datasets-2.1.0 frozenlist-1.3.0 fsspec-2022.3.0 multidict-6.0.2 responses-0.18.0 urllib3-1.25.11 xxhash-3.0.0 yarl-1.7.2

# %%
# Clone the dataset repository from github
# !git clone https://github.com/leocomelli/score-freetext-answer.git
# Out:
# Cloning into 'score-freetext-answer'...
# remote: Enumerating objects: 511, done.
# remote: Total 511 (delta 0), reused 0 (delta 0), pack-reused 511
# Receiving objects: 100% (511/511), 478.34 KiB | 17.08 MiB/s, done.
# Resolving deltas: 100% (263/263), done.

# %%
import torch
import torch.nn as nn
import os
import matplotlib.pyplot as plt
import copy
import torch.optim as optim
import random
import numpy as np
import pandas as pd
import glob
import xml.etree.ElementTree as ET
from torch.utils.data import DataLoader, Dataset
from torch.cuda.amp import autocast, GradScaler
from tqdm import tqdm
from transformers import AutoTokenizer, AutoModel, AdamW, get_linear_schedule_with_warmup
from datasets import load_dataset, load_metric

os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
# Check that we are using 100% of GPU memory footprint support libraries/code
# from https://github.com/patrickvonplaten/notebooks/blob/master/PyTorch_Reformer.ipynb
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip -q install gputil
# !pip -q install psutil
# !pip -q install humanize
import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
 process = psutil.Process(os.getpid())
 print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
 print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()
# Out:
#   Building wheel for gputil (setup.py) ... done
# Gen RAM Free: 12.1 GB  | Proc size: 811.6 MB
# GPU RAM Free: 15109MB | Used: 0MB | Util   0% | Total 15109MB

# %% [markdown]
# In case GPU utilisation (Util) is not at 0%, you can uncomment and run the following line to kill all processes to get the full GPU afterwards. Make sure to comment out the line again to not constantly crash the notebook on purpose.

# %%
# !kill -9 -1

# %% [markdown]
# ## Loading the dataset

# %%
training_data_directory = '/content/score-freetext-answer/src/main/resources/corpus/semeval2013-task7/training/2way/sciEntsBank'
test_data_directory = '/content/score-freetext-answer/src/main/resources/corpus/semeval2013-task7/test/2way/sciEntsBank/test-unseen-questions'

# %%
def parse_xml_file(xml_file_path):

  question = ""
  ref = ""
  results = []

  for elem in ET.parse(xml_file_path).getroot():
    if elem.tag == 'questionText':
      question = elem.text
    for subelem in elem:
      if subelem.tag == 'referenceAnswer':
        ref = subelem.text
      else:
        results.append({
            'question': question,
            'ref': ref,
            'response': subelem.text,
            'score': subelem.attrib['accuracy']
        })

  return results

# %%
training_data = []
test_data = []
num_training_questions = 0
num_test_questions = 0

for data_file in glob.glob(training_data_directory + '/*'):
  training_data += parse_xml_file(data_file)
  num_training_questions += 1

for data_file in glob.glob(test_data_directory + '/*'):
  test_data += parse_xml_file(data_file)
  num_test_questions += 1

print("Number of Training Questions:", num_training_questions)
print("Number of Training Responses:", len(training_data))

print("Number of Test Questions:", num_test_questions)
print("Number of Test Responses:", len(test_data))
# Out:
# Number of Training Questions: 135
# Number of Training Responses: 4969
# Number of Test Questions: 15
# Number of Test Responses: 733

# %%
class ShortAnswerGradingDataset(Dataset):
    def __init__(self, dataset):
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        # Note: I handle the parsing in the data loading from XML section
        # Returns a dict for each item with the following keys: 'question', 'ref', 'response', 'score' all of type 'str'
        return self.dataset[idx]

# %%
training_dataset = ShortAnswerGradingDataset(training_data)
test_dataset = ShortAnswerGradingDataset(test_data)

# %%
# for training_item in training_dataset:
#   print(training_item)

# for test_item in test_dataset:
#   print(test_item)
print(training_dataset[0])
print(len(training_dataset))
print(len(test_dataset))
# Out:
# {'question': "Why was the siren's sound designed to have this property?", 'ref': 'So that people notice the sound.', 'response': 'Because so it can tell people to get out of the way in case of a fire.', 'score': 'correct'}
# 4969
# 733

# %%
print(0 if 0==1 else 1)
# Out:
# 1

# %%
# Concate the reference answer and student answer to creat new input for both train and test set
number_test = 100
train_ref = []
train_res = []
train_score = []
test_ref = []
test_res = []
test_score = []

for training_item in training_data:
  train_ref.append(training_item["ref"])
  train_res.append(training_item["response"])
  train_score.append(0 if training_item["score"]=='incorrect' else 1)


for test_item in test_dataset:
  test_ref.append(test_item["ref"])
  test_res.append(test_item["response"])
  test_score.append(0 if test_item["score"]=='incorrect' else 1)

train = {'idx': list(range(number_test,len( training_data))), 'label': train_score[number_test:], 'sentence1': train_ref[number_test:], 'sentence2': train_res[number_test:]}
valid = {'idx': list(range(number_test)), 'label': train_score[0:number_test], 'sentence1': train_ref[0:number_test], 'sentence2': train_res[0:number_test]}
test = {'idx': list(range(len(test_dataset))), 'label': test_score, 'sentence1': test_ref, 'sentence2': test_res}


# Transform data into pandas dataframes
df_train = pd.DataFrame(train)
df_valid = pd.DataFrame(valid)
df_test = pd.DataFrame(test)

# %%
print(df_train.shape)
print(df_valid.shape)
print(df_test.shape)
# Out:
# (4869, 4)
# (100, 4)
# (733, 4)

# %%
df_train.head()
# Out:
#    idx  label                                          sentence1  \
# 0  100      0  You can see how much time is taken for the ear...
# 1  101      0  You can see how much time is taken for the ear...
# 2  102      0  You can see how much time is taken for the ear...
# 3  103      0  You can see how much time is taken for the ear...
# 4  104      0  You can see how much time is taken for the ear...
#
#                                            sentence2
# 0  The information you get is that you do not see...
# 1  You cannot see in the maps, the time where the...
# 2                               The time it happens.
# 3  The information that you do get is what happen...
# 4  The information I did not get from the stream ...

# %% [markdown]
# ## Classes and functions

# %%
class CustomDataset(Dataset):

    def __init__(self, data, maxlen, with_labels=True, bert_model='bert-base-uncased'):

        self.data = data  # pandas dataframe
        #Initialize the tokenizer
        self.tokenizer = AutoTokenizer.from_pretrained(bert_model)  

        self.maxlen = maxlen
        self.with_labels = with_labels 

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):

        # Selecting sentence1 and sentence2 at the specified index in the data frame
        sent1 = str(self.data.loc[index, 'sentence1'])
        sent2 = str(self.data.loc[index, 'sentence2'])

        # Tokenize the pair of sentences to get token ids, attention masks and token type ids
        encoded_pair = self.tokenizer(sent1, sent2, 
                                      padding='max_length',  # Pad to max_length
                                      truncation=True,  # Truncate to max_length
                                      max_length=self.maxlen,  
                                      return_tensors='pt')  # Return torch.Tensor objects
        
        token_ids = encoded_pair['input_ids'].squeeze(0)  # tensor of token ids
        attn_masks = encoded_pair['attention_mask'].squeeze(0)  # binary tensor with "0" for padded values and "1" for the other values
        token_type_ids = encoded_pair['token_type_ids'].squeeze(0)  # binary tensor with "0" for the 1st sentence tokens & "1" for the 2nd sentence tokens

        if self.with_labels:  # True if the dataset has labels
            label = self.data.loc[index, 'label']
            return token_ids, attn_masks, token_type_ids, label  
        else:
            return token_ids, attn_masks, token_type_ids

# %%
class SentencePairClassifier(nn.Module):

    def __init__(self, bert_model="bert-base-uncased", freeze_bert=False):
        super(SentencePairClassifier, self).__init__()
        #  Instantiating BERT-based model object
        self.bert_layer = AutoModel.from_pretrained(bert_model)

        #  Fix the hidden-state size of the encoder outputs (If you want to add other pre-trained models here, search for the encoder output size)
        if bert_model == "albert-base-v2":  # 12M parameters
            hidden_size = 768
        elif bert_model == "albert-large-v2":  # 18M parameters
            hidden_size = 1024
        elif bert_model == "albert-xlarge-v2":  # 60M parameters
            hidden_size = 2048
        elif bert_model == "albert-xxlarge-v2":  # 235M parameters
            hidden_size = 4096
        elif bert_model == "bert-base-uncased": # 110M parameters
            hidden_size = 768
        elif bert_model == 'allenai/scibert_scivocab_uncased':
            hidden_size = 768

        # Freeze bert layers and only train the classification layer weights
        if freeze_bert:
            for p in self.bert_layer.parameters():
                p.requires_grad = False

        # Classification layer
        self.cls_layer = nn.Linear(hidden_size, 1)

        self.dropout = nn.Dropout(p=0.1)

    @autocast()  # run in mixed precision
    def forward(self, input_ids, attn_masks, token_type_ids):
        '''
        Inputs:
            -input_ids : Tensor  containing token ids
            -attn_masks : Tensor containing attention masks to be used to focus on non-padded values
            -token_type_ids : Tensor containing token type ids to be used to identify sentence1 and sentence2
        '''

        # Feeding the inputs to the BERT-based model to obtain contextualized representations
        model_output = self.bert_layer(input_ids, attn_masks, token_type_ids)

        # Feeding to the classifier layer the last layer hidden-state of the [CLS] token further processed by a
        # Linear Layer and a Tanh activation. The Linear layer weights were trained from the sentence order prediction (ALBERT) or next sentence prediction (BERT)
        # objective during pre-training.

        logits = self.cls_layer(self.dropout(model_output.pooler_output))

        return logits

# %%
def set_seed(seed):
    """ Set all seeds to make results reproducible """
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    

def evaluate_loss(net, device, criterion, dataloader):
    net.eval()

    mean_loss = 0
    count = 0

    with torch.no_grad():
        for it, (seq, attn_masks, token_type_ids, labels) in enumerate(tqdm(dataloader)):
            seq, attn_masks, token_type_ids, labels = \
                seq.to(device), attn_masks.to(device), token_type_ids.to(device), labels.to(device)
            logits = net(seq, attn_masks, token_type_ids)
            mean_loss += criterion(logits.squeeze(-1), labels.float()).item()
            count += 1

    return mean_loss / count

# %%
print("Creation of the models' folder...")
# !mkdir models
# Out:
# Creation of the models' folder...

# %% [markdown]
# Link for mixed precision training, gradient scaling and gradient accumulation  : https://pytorch.org/docs/stable/notes/amp_examples.html#amp-examples
#
# If you would like to learn more about Training Neural Nets on Larger Batches, I suggest reading this post of Thomas Wolf :
# https://medium.com/huggingface/training-larger-batches-practical-tips-on-1-gpu-multi-gpu-distributed-setups-ec88c3e51255

# %%
def train_bert(net, criterion, opti, lr, lr_scheduler, train_loader, val_loader, epochs, iters_to_accumulate):

    best_loss = np.Inf
    best_ep = 1
    nb_iterations = len(train_loader)
    print_every = nb_iterations // 5  # print the training loss 5 times per epoch
    iters = []
    train_losses = []
    val_losses = []

    scaler = GradScaler()

    for ep in range(epochs):

        net.train()
        running_loss = 0.0
        for it, (seq, attn_masks, token_type_ids, labels) in enumerate(tqdm(train_loader)):

            # Converting to cuda tensors
            seq, attn_masks, token_type_ids, labels = \
                seq.to(device), attn_masks.to(device), token_type_ids.to(device), labels.to(device)
    
            # Enables autocasting for the forward pass (model + loss)
            with autocast():
                # Obtaining the logits from the model
                logits = net(seq, attn_masks, token_type_ids)

                # Computing loss
                loss = criterion(logits.squeeze(-1), labels.float())
                loss = loss / iters_to_accumulate  # Normalize the loss because it is averaged

            # Backpropagating the gradients
            # Scales loss.  Calls backward() on scaled loss to create scaled gradients.
            scaler.scale(loss).backward()

            if (it + 1) % iters_to_accumulate == 0:
                # Optimization step
                # scaler.step() first unscales the gradients of the optimizer's assigned params.
                # If these gradients do not contain infs or NaNs, opti.step() is then called,
                # otherwise, opti.step() is skipped.
                scaler.step(opti)
                # Updates the scale for next iteration.
                scaler.update()
                # Adjust the learning rate based on the number of iterations.
                lr_scheduler.step()
                # Clear gradients
                opti.zero_grad()


            running_loss += loss.item()

            if (it + 1) % print_every == 0:  # Print training loss information
                print()
                print("Iteration {}/{} of epoch {} complete. Loss : {} "
                      .format(it+1, nb_iterations, ep+1, running_loss / print_every))

                running_loss = 0.0


        val_loss = evaluate_loss(net, device, criterion, val_loader)  # Compute validation loss
        print()
        print("Epoch {} complete! Validation Loss : {}".format(ep+1, val_loss))

        if val_loss < best_loss:
            print("Best validation loss improved from {} to {}".format(best_loss, val_loss))
            print()
            net_copy = copy.deepcopy(net)  # save a copy of the model
            best_loss = val_loss
            best_ep = ep + 1

    # Saving the model
    path_to_model='models/{}_lr_{}_val_loss_{}_ep_{}.pt'.format(bert_model.replace('/', '_'), lr, round(best_loss, 5), best_ep)
    torch.save(net_copy.state_dict(), path_to_model)
    print("The model has been saved in {}".format(path_to_model))

    del loss
    torch.cuda.empty_cache()

# %% [markdown]
# ## Parameters

# %%
bert_model = "bert-base-uncased"  # 'albert-base-v2', 'albert-large-v2', 'albert-xlarge-v2', 'albert-xxlarge-v2', 'bert-base-uncased', ...
freeze_bert = True  # if True, freeze the encoder weights and only update the classification layer weights
maxlen = 128  # maximum length of the tokenized input sentence pair : if greater than "maxlen", the input is truncated and else if smaller, the input is padded
bs = 20  # batch size
iters_to_accumulate = 2  # the gradient accumulation adds gradients over an effective batch of size : bs * iters_to_accumulate. If set to "1", you get the usual batch size
lr = 5e-4  # learning rate
epochs = 6  # number of training epochs

# %% [markdown]
# ## Training and validation

# %% [markdown]
# Link for the AdamW optimizer and the learning rate scheduler :
# https://huggingface.co/transformers/main_classes/optimizer_schedules.html

# %%
#  Set all seeds to make reproducible results
set_seed(1)

# Creating instances of training and validation set
print("Reading training data...")
train_set = CustomDataset(df_train, maxlen, bert_model)
print("Reading validation data...")
val_set = CustomDataset(df_valid, maxlen, bert_model)
# Creating instances of training and validation dataloaders
train_loader = DataLoader(train_set, batch_size=bs, num_workers=5)
val_loader = DataLoader(val_set, batch_size=bs, num_workers=5)


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
net = SentencePairClassifier(bert_model, freeze_bert=freeze_bert)

if torch.cuda.device_count() > 1:  # if multiple GPUs
    print("Let's use", torch.cuda.device_count(), "GPUs!")
    net = nn.DataParallel(net)

net.to(device)

criterion = nn.BCEWithLogitsLoss()
opti = AdamW(net.parameters(), lr=lr, weight_decay=1e-2)
num_warmup_steps = 0 # The number of steps for the warmup phase.
num_training_steps = epochs * len(train_loader)  # The total number of training steps
t_total = (len(train_loader) // iters_to_accumulate) * epochs  # Necessary to take into account Gradient accumulation
lr_scheduler = get_linear_schedule_with_warmup(optimizer=opti, num_warmup_steps=num_warmup_steps, num_training_steps=t_total)

train_bert(net, criterion, opti, lr, lr_scheduler, train_loader, val_loader, epochs, iters_to_accumulate)
# Out:
# Reading training data...
# Reading validation data...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Downloading:   0%|          | 0.00/420M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
#  20%|██        | 50/244 [00:02<00:09, 20.53it/s]
# Iteration 48/244 of epoch 1 complete. Loss : 0.3522648327052593
#  40%|████      | 98/244 [00:05<00:07, 20.45it/s]
# Iteration 96/244 of epoch 1 complete. Loss : 0.32805893911669654
#  60%|█████▉    | 146/244 [00:07<00:04, 20.30it/s]
# Iteration 144/244 of epoch 1 complete. Loss : 0.33627312382062274
#  80%|███████▉  | 194/244 [00:09<00:02, 20.69it/s]
# Iteration 192/244 of epoch 1 complete. Loss : 0.36195255691806477
#  99%|█████████▉| 242/244 [00:12<00:00, 20.45it/s]
# Iteration 240/244 of epoch 1 complete. Loss : 0.33573864959180355
# 100%|██████████| 244/244 [00:12<00:00, 19.55it/s]
# 100%|██████████| 5/5 [00:00<00:00,  8.05it/s]
# Epoch 1 complete! Validation Loss : 0.6959778010845185
# Best validation loss improved from inf to 0.6959778010845185
#  21%|██        | 51/244 [00:02<00:09, 20.34it/s]
# Iteration 48/244 of epoch 2 complete. Loss : 0.34241660746435326
#  41%|████      | 99/244 [00:05<00:07, 20.45it/s]
# Iteration 96/244 of epoch 2 complete. Loss : 0.31508357139925164
#  60%|██████    | 147/244 [00:07<00:04, 20.29it/s]
# Iteration 144/244 of epoch 2 complete. Loss : 0.32979377017666894
#  80%|███████▉  | 195/244 [00:09<00:02, 20.17it/s]
# Iteration 192/244 of epoch 2 complete. Loss : 0.34421926115949947
# 100%|█████████▉| 243/244 [00:12<00:00, 20.22it/s]
# Iteration 240/244 of epoch 2 complete. Loss : 0.3306786175817251
# 100%|██████████| 244/244 [00:12<00:00, 19.62it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.75it/s]
# Epoch 2 complete! Validation Loss : 0.6882092356681824
# Best validation loss improved from 0.6959778010845185 to 0.6882092356681824
#  20%|██        | 50/244 [00:02<00:09, 19.78it/s]
# Iteration 48/244 of epoch 3 complete. Loss : 0.33696525481839973
#  41%|████      | 100/244 [00:05<00:07, 19.94it/s]
# Iteration 96/244 of epoch 3 complete. Loss : 0.3150783705835541
#  61%|██████    | 148/244 [00:07<00:04, 19.92it/s]
# Iteration 144/244 of epoch 3 complete. Loss : 0.32569303270429373
#  80%|███████▉  | 195/244 [00:10<00:02, 19.43it/s]
# Iteration 192/244 of epoch 3 complete. Loss : 0.33722567403068143
# 100%|█████████▉| 243/244 [00:12<00:00, 19.80it/s]
# Iteration 240/244 of epoch 3 complete. Loss : 0.329235197044909
# 100%|██████████| 244/244 [00:12<00:00, 19.12it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.74it/s]
# Epoch 3 complete! Validation Loss : 0.669543468952179
# Best validation loss improved from 0.6882092356681824 to 0.669543468952179
#  21%|██        | 51/244 [00:03<00:10, 18.72it/s]
# Iteration 48/244 of epoch 4 complete. Loss : 0.3303165103619297
#  40%|████      | 98/244 [00:05<00:07, 19.70it/s]
# Iteration 96/244 of epoch 4 complete. Loss : 0.3152905385941267
#  60%|█████▉    | 146/244 [00:08<00:04, 19.68it/s]
# Iteration 144/244 of epoch 4 complete. Loss : 0.3209957579771678
#  80%|███████▉  | 195/244 [00:10<00:02, 19.81it/s]
# Iteration 192/244 of epoch 4 complete. Loss : 0.3282302375882864
# 100%|█████████▉| 243/244 [00:13<00:00, 19.64it/s]
# Iteration 240/244 of epoch 4 complete. Loss : 0.3278226175655921
# 100%|██████████| 244/244 [00:13<00:00, 18.01it/s]
# 100%|██████████| 5/5 [00:00<00:00,  8.03it/s]
# Epoch 4 complete! Validation Loss : 0.6546350061893463
# Best validation loss improved from 0.669543468952179 to 0.6546350061893463
#  21%|██        | 51/244 [00:02<00:09, 19.70it/s]
# Iteration 48/244 of epoch 5 complete. Loss : 0.3300441578030586
#  41%|████      | 99/244 [00:05<00:07, 19.45it/s]
# Iteration 96/244 of epoch 5 complete. Loss : 0.3162546247864763
#  60%|██████    | 147/244 [00:07<00:05, 19.05it/s]
# Iteration 144/244 of epoch 5 complete. Loss : 0.31200413902600604
#  80%|███████▉  | 195/244 [00:10<00:02, 19.37it/s]
# Iteration 192/244 of epoch 5 complete. Loss : 0.32578602029631537
# 100%|█████████▉| 243/244 [00:12<00:00, 19.38it/s]
# Iteration 240/244 of epoch 5 complete. Loss : 0.3277521611501773
# 100%|██████████| 244/244 [00:13<00:00, 18.74it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.78it/s]
# Epoch 5 complete! Validation Loss : 0.6493316769599915
# Best validation loss improved from 0.6546350061893463 to 0.6493316769599915
#  20%|██        | 50/244 [00:02<00:09, 19.45it/s]
# Iteration 48/244 of epoch 6 complete. Loss : 0.32633860409259796
#  40%|████      | 98/244 [00:05<00:07, 19.34it/s]
# Iteration 96/244 of epoch 6 complete. Loss : 0.321514551838239
#  60%|█████▉    | 146/244 [00:07<00:05, 19.50it/s]
# Iteration 144/244 of epoch 6 complete. Loss : 0.3086075863490502
#  80%|███████▉  | 194/244 [00:10<00:02, 19.52it/s]
# Iteration 192/244 of epoch 6 complete. Loss : 0.32162291401376325
#  99%|█████████▉| 242/244 [00:12<00:00, 19.49it/s]
# Iteration 240/244 of epoch 6 complete. Loss : 0.32918917542944354
# 100%|██████████| 244/244 [00:13<00:00, 18.76it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.58it/s]
# Epoch 6 complete! Validation Loss : 0.6960294842720032
# The model has been saved in models/bert-base-uncased_lr_0.0005_val_loss_0.64933_ep_5.pt

# %% [markdown]
# You can download the model saved in the folder "models" by browsing the files on the left of the colab notebook

# %%
# If you encounter a CUDA out of memory error: 
# - uncomment the kill command, run the "kill" command (and comment it)
# - reduce the batch size
# - then run all cells from the begining 

# !kill -9 -1

# %% [markdown]
# ## Prediction

# %%
print("Creation of the results' folder...")
# !mkdir results
# Out:
# Creation of the results' folder...

# %%
def get_probs_from_logits(logits):
    """
    Converts a tensor of logits into an array of probabilities by applying the sigmoid function
    """
    probs = torch.sigmoid(logits.unsqueeze(-1))
    return probs.detach().cpu().numpy()

def test_prediction(net, device, dataloader, with_labels=True, result_file="results/output.txt"):
    """
    Predict the probabilities on a dataset with or without labels and print the result in a file
    """
    net.eval()
    w = open(result_file, 'w')
    probs_all = []

    with torch.no_grad():
        if with_labels:
            for seq, attn_masks, token_type_ids, _ in tqdm(dataloader):
                seq, attn_masks, token_type_ids = seq.to(device), attn_masks.to(device), token_type_ids.to(device)
                logits = net(seq, attn_masks, token_type_ids)
                probs = get_probs_from_logits(logits.squeeze(-1)).squeeze(-1)
                probs_all += probs.tolist()
        else:
            for seq, attn_masks, token_type_ids in tqdm(dataloader):
                seq, attn_masks, token_type_ids = seq.to(device), attn_masks.to(device), token_type_ids.to(device)
                logits = net(seq, attn_masks, token_type_ids)
                probs = get_probs_from_logits(logits.squeeze(-1)).squeeze(-1)
                probs_all += probs.tolist()

    w.writelines(str(prob)+'\n' for prob in probs_all)
    w.close()

# %% [markdown]
# I'm sharing below an ALBERT pre-trained model (45 Mo) so you can reproduce my results on the MRPC validation set (**91.19** as F1 score and **87.5** as accuracy). It's just in case but if all the code run as expected, you should get after the model training the correct model in the *models* folder
#
# You can download it and upload it (~ 3 minutes) in the *models* folder by browsing the files on the left of the colab notebook :
#
# https://drive.google.com/file/d/1AcRLGvALAH3BVSiDVjY_b8CggJgVfksp/view?usp=sharing

# %%
path_to_model = '/content/models/bert-base-uncased_lr_0.0005_val_loss_0.64933_ep_5.pt'  
# path_to_model = '/content/models/...'  # You can add here your trained model

path_to_output_file = 'results/output.txt'

print("Reading test data...")
test_set = CustomDataset(df_test, maxlen, bert_model)
test_loader = DataLoader(test_set, batch_size=bs, num_workers=5)

model = SentencePairClassifier(bert_model)
if torch.cuda.device_count() > 1:  # if multiple GPUs
    print("Let's use", torch.cuda.device_count(), "GPUs!")
    model = nn.DataParallel(model)

print()
print("Loading the weights of the model...")
model.load_state_dict(torch.load(path_to_model))
model.to(device)

print("Predicting on test data...")
test_prediction(net=model, device=device, dataloader=test_loader, with_labels=True,  # set the with_labels parameter to False if your want to get predictions on a dataset without labels
                result_file=path_to_output_file)
print()
print("Predictions are available in : {}".format(path_to_output_file))
# Out:
# Reading test data...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Loading the weights of the model...
# Predicting on test data...
# 100%|██████████| 37/37 [00:02<00:00, 16.47it/s]
# Predictions are available in : results/output.txt

# %% [markdown]
# You can download the predictions saved in the folder "results" by browsing the files on the left of the colab notebook

# %% [markdown]
# ## Evaluation

# %%
path_to_output_file = 'results/output.txt'  # path to the file with prediction probabilities

labels_test = df_test['label']  # true labels

probs_test = pd.read_csv(path_to_output_file, header=None)[0]  # prediction probabilities

threshold = 0.5   # you can adjust this threshold for your own dataset
preds_test=(probs_test>=threshold).astype('uint8') # predicted labels using the above fixed threshold

metric = load_metric("glue", "mrpc")

# %%
# Compute the accuracy and F1 scores
metric._compute(predictions=preds_test, references=labels_test)
# Out:
# {'accuracy': 0.5552523874488404, 'f1': 0.5302593659942364}

# %%
for i in range(len(preds_test)):
  if preds_test[i] != labels_test[i]:
    print(i)
    print("Ground Truth: ", labels_test[i])
    print("Test prediction probability: ",probs_test[i])
# Out:
# 1
# Ground Truth:  0
# Test prediction probability:  0.5625
# 4
# Ground Truth:  1
# Test prediction probability:  0.350341796875
# 6
# Ground Truth:  1
# Test prediction probability:  0.498779296875
# 7
# Ground Truth:  0
# Test prediction probability:  0.52685546875
# 10
# Ground Truth:  0
# Test prediction probability:  0.53759765625
# 11
# Ground Truth:  0
# Test prediction probability:  0.52783203125
# 14
# Ground Truth:  0
# Test prediction probability:  0.57373046875
# 24
# Ground Truth:  0
# Test prediction probability:  0.5576171875
# 25
# Ground Truth:  0
# Test prediction probability:  0.5302734375
# 26
# Ground Truth:  1
# Test prediction probability:  0.41845703125
# 27
# Ground Truth:  0
# Test prediction probability:  0.564453125
# 28
# Ground Truth:  0
# Test prediction probability:  0.52587890625
# 33
# Ground Truth:  0
# Test prediction probability:  0.5322265625
# 45
# Ground Truth:  1
# Test prediction probability:  0.48583984375
# 48
# Ground Truth:  1
# Test prediction probability:  0.43310546875
# 50
# Ground Truth:  1
# Test prediction probability:  0.459716796875
# 51
# Ground Truth:  1
# Test prediction probability:  0.493896484375
# 53
# Ground Truth:  0
# Test prediction probability:  0.53076171875
# 56
# Ground Truth:  1
# Test prediction probability:  0.4794921875
# 60
# Ground Truth:  1
# Test prediction probability:  0.38720703125
# 61
# Ground Truth:  1
# Test prediction probability:  0.450439453125
# 62
# Ground Truth:  1
# Test prediction probability:  0.44580078125
# 65
# Ground Truth:  1
# Test prediction probability:  0.378173828125
# 66
# Ground Truth:  1
# Test prediction probability:  0.346435546875
# 67
# Ground Truth:  1
# Test prediction probability:  0.46923828125
# 70
# Ground Truth:  1
# Test prediction probability:  0.3701171875
# 72
# Ground Truth:  1
# Test prediction probability:  0.43212890625
# 76
# Ground Truth:  0
# Test prediction probability:  0.57177734375
# 79
# Ground Truth:  1
# Test prediction probability:  0.4248046875
# 81
# Ground Truth:  1
# Test prediction probability:  0.462890625
# 82
# Ground Truth:  1
# Test prediction probability:  0.477294921875
# 91
# Ground Truth:  1
# Test prediction probability:  0.399658203125
# 97
# Ground Truth:  1
# Test prediction probability:  0.427978515625
# 99
# Ground Truth:  1
# Test prediction probability:  0.48583984375
# 103
# Ground Truth:  1
# Test prediction probability:  0.428466796875
# 112
# Ground Truth:  0
# Test prediction probability:  0.501953125
# 114
# Ground Truth:  0
# Test prediction probability:  0.51513671875
# 116
# Ground Truth:  1
# Test prediction probability:  0.4560546875
# 118
# Ground Truth:  1
# Test prediction probability:  0.473388671875
# 122
# Ground Truth:  1
# Test prediction probability:  0.45703125
# 123
# Ground Truth:  1
# Test prediction probability:  0.38134765625
# 125
# Ground Truth:  1
# Test prediction probability:  0.3984375
# 126
# Ground Truth:  0
# Test prediction probability:  0.50830078125
# 130
# Ground Truth:  1
# Test prediction probability:  0.427490234375
# 134
# Ground Truth:  1
# Test prediction probability:  0.321533203125
# 136
# Ground Truth:  1
# Test prediction probability:  0.482177734375
# 137
# Ground Truth:  1
# Test prediction probability:  0.36328125
# 138
# Ground Truth:  1
# Test prediction probability:  0.410888671875
# 139
# Ground Truth:  1
# Test prediction probability:  0.46875
# 140
# Ground Truth:  0
# Test prediction probability:  0.5341796875
# 149
# Ground Truth:  0
# Test prediction probability:  0.556640625
# 150
# Ground Truth:  1
# Test prediction probability:  0.489501953125
# 152
# Ground Truth:  1
# Test prediction probability:  0.456298828125
# 156
# Ground Truth:  1
# Test prediction probability:  0.452392578125
# 158
# Ground Truth:  1
# Test prediction probability:  0.404296875
# 160
# Ground Truth:  1
# Test prediction probability:  0.44140625
# 161
# Ground Truth:  1
# Test prediction probability:  0.427001953125
# 162
# Ground Truth:  0
# Test prediction probability:  0.5634765625
# 163
# Ground Truth:  0
# Test prediction probability:  0.525390625
# 164
# Ground Truth:  0
# Test prediction probability:  0.5625
# 165
# Ground Truth:  0
# Test prediction probability:  0.58349609375
# 166
# Ground Truth:  0
# Test prediction probability:  0.56591796875
# 167
# Ground Truth:  0
# Test prediction probability:  0.56884765625
# 168
# Ground Truth:  0
# Test prediction probability:  0.5537109375
# 169
# Ground Truth:  0
# Test prediction probability:  0.5361328125
# 170
# Ground Truth:  0
# Test prediction probability:  0.521484375
# 171
# Ground Truth:  0
# Test prediction probability:  0.59814453125
# 173
# Ground Truth:  0
# Test prediction probability:  0.50439453125
# 174
# Ground Truth:  0
# Test prediction probability:  0.552734375
# 177
# Ground Truth:  0
# Test prediction probability:  0.58642578125
# 180
# Ground Truth:  0
# Test prediction probability:  0.53173828125
# 181
# Ground Truth:  0
# Test prediction probability:  0.5615234375
# 182
# Ground Truth:  0
# Test prediction probability:  0.57470703125
# 184
# Ground Truth:  0
# Test prediction probability:  0.544921875
# 187
# Ground Truth:  0
# Test prediction probability:  0.51220703125
# 188
# Ground Truth:  0
# Test prediction probability:  0.52587890625
# 189
# Ground Truth:  0
# Test prediction probability:  0.51513671875
# 190
# Ground Truth:  0
# Test prediction probability:  0.51318359375
# 192
# Ground Truth:  0
# Test prediction probability:  0.52294921875
# 196
# Ground Truth:  1
# Test prediction probability:  0.436767578125
# 200
# Ground Truth:  0
# Test prediction probability:  0.54541015625
# 201
# Ground Truth:  0
# Test prediction probability:  0.5205078125
# 204
# Ground Truth:  1
# Test prediction probability:  0.474365234375
# 206
# Ground Truth:  0
# Test prediction probability:  0.50830078125
# 208
# Ground Truth:  1
# Test prediction probability:  0.426025390625
# 210
# Ground Truth:  1
# Test prediction probability:  0.4853515625
# 217
# Ground Truth:  0
# Test prediction probability:  0.50927734375
# 218
# Ground Truth:  0
# Test prediction probability:  0.56884765625
# 225
# Ground Truth:  0
# Test prediction probability:  0.513671875
# 226
# Ground Truth:  0
# Test prediction probability:  0.50927734375
# 227
# Ground Truth:  1
# Test prediction probability:  0.48291015625
# 233
# Ground Truth:  1
# Test prediction probability:  0.447265625
# 235
# Ground Truth:  0
# Test prediction probability:  0.5986328125
# 245
# Ground Truth:  1
# Test prediction probability:  0.44384765625
# 249
# Ground Truth:  1
# Test prediction probability:  0.42626953125
# 252
# Ground Truth:  1
# Test prediction probability:  0.484375
# 253
# Ground Truth:  1
# Test prediction probability:  0.3740234375
# 254
# Ground Truth:  0
# Test prediction probability:  0.56884765625
# 255
# Ground Truth:  1
# Test prediction probability:  0.490966796875
# 260
# Ground Truth:  1
# Test prediction probability:  0.484375
# 261
# Ground Truth:  1
# Test prediction probability:  0.412353515625
# 263
# Ground Truth:  1
# Test prediction probability:  0.4970703125
# 264
# Ground Truth:  1
# Test prediction probability:  0.4580078125
# 265
# Ground Truth:  1
# Test prediction probability:  0.385009765625
# 267
# Ground Truth:  1
# Test prediction probability:  0.317626953125
# 268
# Ground Truth:  1
# Test prediction probability:  0.47119140625
# 269
# Ground Truth:  1
# Test prediction probability:  0.484375
# 274
# Ground Truth:  1
# Test prediction probability:  0.42626953125
# 275
# Ground Truth:  1
# Test prediction probability:  0.452880859375
# 280
# Ground Truth:  0
# Test prediction probability:  0.6064453125
# 281
# Ground Truth:  0
# Test prediction probability:  0.623046875
# 282
# Ground Truth:  1
# Test prediction probability:  0.417724609375
# 284
# Ground Truth:  1
# Test prediction probability:  0.484375
# 285
# Ground Truth:  0
# Test prediction probability:  0.5029296875
# 288
# Ground Truth:  1
# Test prediction probability:  0.462890625
# 289
# Ground Truth:  1
# Test prediction probability:  0.442626953125
# 293
# Ground Truth:  1
# Test prediction probability:  0.484375
# 294
# Ground Truth:  1
# Test prediction probability:  0.484375
# 296
# Ground Truth:  1
# Test prediction probability:  0.484375
# 298
# Ground Truth:  0
# Test prediction probability:  0.50390625
# 302
# Ground Truth:  1
# Test prediction probability:  0.476806640625
# 316
# Ground Truth:  1
# Test prediction probability:  0.484375
# 317
# Ground Truth:  1
# Test prediction probability:  0.484375
# 319
# Ground Truth:  1
# Test prediction probability:  0.480712890625
# 321
# Ground Truth:  1
# Test prediction probability:  0.484375
# 322
# Ground Truth:  1
# Test prediction probability:  0.484375
# 324
# Ground Truth:  1
# Test prediction probability:  0.484375
# 334
# Ground Truth:  1
# Test prediction probability:  0.482421875
# 335
# Ground Truth:  1
# Test prediction probability:  0.429931640625
# 336
# Ground Truth:  1
# Test prediction probability:  0.252685546875
# 340
# Ground Truth:  0
# Test prediction probability:  0.5
# 343
# Ground Truth:  1
# Test prediction probability:  0.452880859375
# 344
# Ground Truth:  1
# Test prediction probability:  0.391357421875
# 345
# Ground Truth:  1
# Test prediction probability:  0.480712890625
# 346
# Ground Truth:  1
# Test prediction probability:  0.467041015625
# 347
# Ground Truth:  0
# Test prediction probability:  0.52197265625
# 351
# Ground Truth:  1
# Test prediction probability:  0.42333984375
# 352
# Ground Truth:  1
# Test prediction probability:  0.430419921875
# 353
# Ground Truth:  1
# Test prediction probability:  0.45751953125
# 374
# Ground Truth:  1
# Test prediction probability:  0.443359375
# 377
# Ground Truth:  0
# Test prediction probability:  0.5224609375
# 380
# Ground Truth:  0
# Test prediction probability:  0.5009765625
# 383
# Ground Truth:  1
# Test prediction probability:  0.4111328125
# 387
# Ground Truth:  1
# Test prediction probability:  0.486328125
# 391
# Ground Truth:  0
# Test prediction probability:  0.60400390625
# 402
# Ground Truth:  0
# Test prediction probability:  0.541015625
# 404
# Ground Truth:  1
# Test prediction probability:  0.46240234375
# 405
# Ground Truth:  1
# Test prediction probability:  0.451416015625
# 406
# Ground Truth:  0
# Test prediction probability:  0.5546875
# 408
# Ground Truth:  0
# Test prediction probability:  0.578125
# 409
# Ground Truth:  0
# Test prediction probability:  0.55126953125
# 412
# Ground Truth:  0
# Test prediction probability:  0.5732421875
# 414
# Ground Truth:  0
# Test prediction probability:  0.6064453125
# 415
# Ground Truth:  0
# Test prediction probability:  0.5498046875
# 416
# Ground Truth:  0
# Test prediction probability:  0.5244140625
# 418
# Ground Truth:  0
# Test prediction probability:  0.5859375
# 419
# Ground Truth:  0
# Test prediction probability:  0.58349609375
# 422
# Ground Truth:  0
# Test prediction probability:  0.53662109375
# 423
# Ground Truth:  0
# Test prediction probability:  0.60546875
# 424
# Ground Truth:  0
# Test prediction probability:  0.5185546875
# 425
# Ground Truth:  0
# Test prediction probability:  0.60693359375
# 429
# Ground Truth:  1
# Test prediction probability:  0.496826171875
# 430
# Ground Truth:  0
# Test prediction probability:  0.5478515625
# 432
# Ground Truth:  0
# Test prediction probability:  0.572265625
# 435
# Ground Truth:  1
# Test prediction probability:  0.451416015625
# 436
# Ground Truth:  1
# Test prediction probability:  0.396484375
# 437
# Ground Truth:  1
# Test prediction probability:  0.4521484375
# 438
# Ground Truth:  1
# Test prediction probability:  0.479248046875
# 439
# Ground Truth:  1
# Test prediction probability:  0.453369140625
# 442
# Ground Truth:  1
# Test prediction probability:  0.4638671875
# 445
# Ground Truth:  0
# Test prediction probability:  0.5263671875
# 449
# Ground Truth:  0
# Test prediction probability:  0.58349609375
# 451
# Ground Truth:  0
# Test prediction probability:  0.56982421875
# 456
# Ground Truth:  1
# Test prediction probability:  0.386962890625
# 457
# Ground Truth:  1
# Test prediction probability:  0.484375
# 459
# Ground Truth:  1
# Test prediction probability:  0.46826171875
# 460
# Ground Truth:  0
# Test prediction probability:  0.50634765625
# 465
# Ground Truth:  1
# Test prediction probability:  0.4482421875
# 470
# Ground Truth:  1
# Test prediction probability:  0.43115234375
# 471
# Ground Truth:  0
# Test prediction probability:  0.51953125
# 473
# Ground Truth:  0
# Test prediction probability:  0.57275390625
# 474
# Ground Truth:  1
# Test prediction probability:  0.470458984375
# 475
# Ground Truth:  0
# Test prediction probability:  0.5498046875
# 476
# Ground Truth:  1
# Test prediction probability:  0.48486328125
# 477
# Ground Truth:  0
# Test prediction probability:  0.60693359375
# 478
# Ground Truth:  0
# Test prediction probability:  0.5166015625
# 480
# Ground Truth:  0
# Test prediction probability:  0.59423828125
# 482
# Ground Truth:  1
# Test prediction probability:  0.422119140625
# 484
# Ground Truth:  1
# Test prediction probability:  0.48681640625
# 485
# Ground Truth:  1
# Test prediction probability:  0.462646484375
# 486
# Ground Truth:  1
# Test prediction probability:  0.4306640625
# 487
# Ground Truth:  1
# Test prediction probability:  0.43310546875
# 488
# Ground Truth:  1
# Test prediction probability:  0.48486328125
# 489
# Ground Truth:  0
# Test prediction probability:  0.5078125
# 490
# Ground Truth:  1
# Test prediction probability:  0.452880859375
# 491
# Ground Truth:  0
# Test prediction probability:  0.55615234375
# 494
# Ground Truth:  0
# Test prediction probability:  0.51416015625
# 495
# Ground Truth:  1
# Test prediction probability:  0.37744140625
# 497
# Ground Truth:  1
# Test prediction probability:  0.480224609375
# 499
# Ground Truth:  1
# Test prediction probability:  0.4638671875
# 500
# Ground Truth:  0
# Test prediction probability:  0.546875
# 502
# Ground Truth:  0
# Test prediction probability:  0.56201171875
# 505
# Ground Truth:  1
# Test prediction probability:  0.4931640625
# 507
# Ground Truth:  1
# Test prediction probability:  0.48193359375
# 509
# Ground Truth:  1
# Test prediction probability:  0.34765625
# 511
# Ground Truth:  1
# Test prediction probability:  0.467529296875
# 512
# Ground Truth:  1
# Test prediction probability:  0.451416015625
# 514
# Ground Truth:  0
# Test prediction probability:  0.52587890625
# 515
# Ground Truth:  0
# Test prediction probability:  0.5234375
# 518
# Ground Truth:  1
# Test prediction probability:  0.458984375
# 522
# Ground Truth:  0
# Test prediction probability:  0.51904296875
# 526
# Ground Truth:  1
# Test prediction probability:  0.390380859375
# 527
# Ground Truth:  0
# Test prediction probability:  0.51611328125
# 530
# Ground Truth:  1
# Test prediction probability:  0.461181640625
# 533
# Ground Truth:  0
# Test prediction probability:  0.5263671875
# 537
# Ground Truth:  1
# Test prediction probability:  0.41552734375
# 539
# Ground Truth:  1
# Test prediction probability:  0.379638671875
# 540
# Ground Truth:  0
# Test prediction probability:  0.60986328125
# 542
# Ground Truth:  1
# Test prediction probability:  0.494140625
# 548
# Ground Truth:  0
# Test prediction probability:  0.58642578125
# 551
# Ground Truth:  1
# Test prediction probability:  0.496826171875
# 552
# Ground Truth:  1
# Test prediction probability:  0.49755859375
# 553
# Ground Truth:  0
# Test prediction probability:  0.541015625
# 557
# Ground Truth:  1
# Test prediction probability:  0.4658203125
# 558
# Ground Truth:  0
# Test prediction probability:  0.501953125
# 559
# Ground Truth:  0
# Test prediction probability:  0.53759765625
# 564
# Ground Truth:  0
# Test prediction probability:  0.75
# 565
# Ground Truth:  0
# Test prediction probability:  0.62890625
# 568
# Ground Truth:  0
# Test prediction probability:  0.5224609375
# 569
# Ground Truth:  0
# Test prediction probability:  0.52197265625
# 570
# Ground Truth:  0
# Test prediction probability:  0.61279296875
# 574
# Ground Truth:  1
# Test prediction probability:  0.39892578125
# 575
# Ground Truth:  1
# Test prediction probability:  0.24169921875
# 580
# Ground Truth:  1
# Test prediction probability:  0.40234375
# 582
# Ground Truth:  1
# Test prediction probability:  0.404541015625
# 585
# Ground Truth:  1
# Test prediction probability:  0.33642578125
# 589
# Ground Truth:  1
# Test prediction probability:  0.421142578125
# 590
# Ground Truth:  0
# Test prediction probability:  0.5205078125
# 591
# Ground Truth:  1
# Test prediction probability:  0.346435546875
# 592
# Ground Truth:  1
# Test prediction probability:  0.36474609375
# 593
# Ground Truth:  1
# Test prediction probability:  0.48779296875
# 597
# Ground Truth:  1
# Test prediction probability:  0.3544921875
# 599
# Ground Truth:  1
# Test prediction probability:  0.341796875
# 601
# Ground Truth:  1
# Test prediction probability:  0.341796875
# 612
# Ground Truth:  0
# Test prediction probability:  0.51708984375
# 618
# Ground Truth:  1
# Test prediction probability:  0.48583984375
# 619
# Ground Truth:  1
# Test prediction probability:  0.4794921875
# 620
# Ground Truth:  1
# Test prediction probability:  0.416015625
# 622
# Ground Truth:  1
# Test prediction probability:  0.48291015625
# 623
# Ground Truth:  1
# Test prediction probability:  0.494140625
# 628
# Ground Truth:  1
# Test prediction probability:  0.42431640625
# 631
# Ground Truth:  1
# Test prediction probability:  0.40771484375
# 635
# Ground Truth:  1
# Test prediction probability:  0.455322265625
# 642
# Ground Truth:  0
# Test prediction probability:  0.5
# 643
# Ground Truth:  1
# Test prediction probability:  0.40673828125
# 644
# Ground Truth:  1
# Test prediction probability:  0.4287109375
# 650
# Ground Truth:  1
# Test prediction probability:  0.476806640625
# 652
# Ground Truth:  1
# Test prediction probability:  0.364501953125
# 658
# Ground Truth:  1
# Test prediction probability:  0.345703125
# 660
# Ground Truth:  1
# Test prediction probability:  0.485107421875
# 663
# Ground Truth:  1
# Test prediction probability:  0.298828125
# 665
# Ground Truth:  1
# Test prediction probability:  0.30517578125
# 666
# Ground Truth:  1
# Test prediction probability:  0.343505859375
# 668
# Ground Truth:  1
# Test prediction probability:  0.36328125
# 669
# Ground Truth:  1
# Test prediction probability:  0.30224609375
# 671
# Ground Truth:  1
# Test prediction probability:  0.289306640625
# 672
# Ground Truth:  1
# Test prediction probability:  0.344970703125
# 674
# Ground Truth:  1
# Test prediction probability:  0.35546875
# 675
# Ground Truth:  1
# Test prediction probability:  0.376708984375
# 676
# Ground Truth:  1
# Test prediction probability:  0.40283203125
# 679
# Ground Truth:  1
# Test prediction probability:  0.33056640625
# 682
# Ground Truth:  1
# Test prediction probability:  0.3564453125
# 683
# Ground Truth:  1
# Test prediction probability:  0.3466796875
# 684
# Ground Truth:  1
# Test prediction probability:  0.2890625
# 685
# Ground Truth:  1
# Test prediction probability:  0.3095703125
# 686
# Ground Truth:  1
# Test prediction probability:  0.337646484375
# 687
# Ground Truth:  1
# Test prediction probability:  0.364013671875
# 688
# Ground Truth:  1
# Test prediction probability:  0.288818359375
# 690
# Ground Truth:  1
# Test prediction probability:  0.418701171875
# 691
# Ground Truth:  1
# Test prediction probability:  0.389404296875
# 702
# Ground Truth:  0
# Test prediction probability:  0.50390625
# 703
# Ground Truth:  0
# Test prediction probability:  0.5517578125
# 715
# Ground Truth:  0
# Test prediction probability:  0.5244140625
# 721
# Ground Truth:  1
# Test prediction probability:  0.444580078125
# 725
# Ground Truth:  0
# Test prediction probability:  0.6171875

# %%
### SciBERT

# n = 280 false positive
# n = 425
# n = 281
# n = 171
# n = 564 #false positive
# n = 540 
# n = 565
n = 414

# n =663 false negative
# n = 267 false negative
# n = 575
# n  =585
# n = 684
# n = 125
# n = 336

print(test_data[n]['question'])
print(test_data[n]['score'])
print(df_test['label'].loc[n])
print(probs_test[n])
print(df_test['sentence1'].loc[n])
print(df_test['sentence2'].loc[n])

# %%
for i in range(len(preds_test)):
  if preds_test[i] != labels_test[i]:
    print(i)
    print("Ground Truth: ", labels_test[i])
    print("Test prediction probability: ",probs_test[i])
# Out:
# 0
# Ground Truth:  0
# Test prediction probability:  0.5048828125
# 1
# Ground Truth:  0
# Test prediction probability:  0.5400390625
# 2
# Ground Truth:  0
# Test prediction probability:  0.5478515625
# 3
# Ground Truth:  0
# Test prediction probability:  0.52685546875
# 5
# Ground Truth:  0
# Test prediction probability:  0.52294921875
# 8
# Ground Truth:  0
# Test prediction probability:  0.53125
# 9
# Ground Truth:  0
# Test prediction probability:  0.5146484375
# 10
# Ground Truth:  0
# Test prediction probability:  0.548828125
# 11
# Ground Truth:  0
# Test prediction probability:  0.544921875
# 14
# Ground Truth:  0
# Test prediction probability:  0.54443359375
# 15
# Ground Truth:  0
# Test prediction probability:  0.5078125
# 17
# Ground Truth:  0
# Test prediction probability:  0.50439453125
# 18
# Ground Truth:  0
# Test prediction probability:  0.5361328125
# 19
# Ground Truth:  0
# Test prediction probability:  0.5185546875
# 21
# Ground Truth:  0
# Test prediction probability:  0.51708984375
# 22
# Ground Truth:  0
# Test prediction probability:  0.53466796875
# 23
# Ground Truth:  0
# Test prediction probability:  0.5
# 24
# Ground Truth:  0
# Test prediction probability:  0.541015625
# 25
# Ground Truth:  0
# Test prediction probability:  0.55322265625
# 27
# Ground Truth:  0
# Test prediction probability:  0.5517578125
# 28
# Ground Truth:  0
# Test prediction probability:  0.5419921875
# 29
# Ground Truth:  0
# Test prediction probability:  0.52734375
# 36
# Ground Truth:  0
# Test prediction probability:  0.5302734375
# 37
# Ground Truth:  0
# Test prediction probability:  0.5458984375
# 41
# Ground Truth:  0
# Test prediction probability:  0.5478515625
# 54
# Ground Truth:  0
# Test prediction probability:  0.54638671875
# 58
# Ground Truth:  0
# Test prediction probability:  0.51220703125
# 60
# Ground Truth:  1
# Test prediction probability:  0.326904296875
# 61
# Ground Truth:  1
# Test prediction probability:  0.4931640625
# 65
# Ground Truth:  1
# Test prediction probability:  0.39599609375
# 66
# Ground Truth:  1
# Test prediction probability:  0.456298828125
# 76
# Ground Truth:  0
# Test prediction probability:  0.5224609375
# 78
# Ground Truth:  0
# Test prediction probability:  0.51953125
# 83
# Ground Truth:  0
# Test prediction probability:  0.55419921875
# 95
# Ground Truth:  0
# Test prediction probability:  0.556640625
# 112
# Ground Truth:  0
# Test prediction probability:  0.56787109375
# 114
# Ground Truth:  0
# Test prediction probability:  0.5537109375
# 116
# Ground Truth:  1
# Test prediction probability:  0.451416015625
# 121
# Ground Truth:  0
# Test prediction probability:  0.52294921875
# 124
# Ground Truth:  0
# Test prediction probability:  0.537109375
# 126
# Ground Truth:  0
# Test prediction probability:  0.5263671875
# 128
# Ground Truth:  0
# Test prediction probability:  0.5400390625
# 131
# Ground Truth:  0
# Test prediction probability:  0.50390625
# 132
# Ground Truth:  0
# Test prediction probability:  0.5361328125
# 140
# Ground Truth:  0
# Test prediction probability:  0.552734375
# 145
# Ground Truth:  0
# Test prediction probability:  0.5380859375
# 148
# Ground Truth:  0
# Test prediction probability:  0.537109375
# 149
# Ground Truth:  0
# Test prediction probability:  0.55615234375
# 157
# Ground Truth:  0
# Test prediction probability:  0.5126953125
# 162
# Ground Truth:  0
# Test prediction probability:  0.5048828125
# 188
# Ground Truth:  0
# Test prediction probability:  0.54296875
# 190
# Ground Truth:  0
# Test prediction probability:  0.5009765625
# 192
# Ground Truth:  0
# Test prediction probability:  0.50390625
# 193
# Ground Truth:  1
# Test prediction probability:  0.484130859375
# 198
# Ground Truth:  0
# Test prediction probability:  0.5107421875
# 200
# Ground Truth:  0
# Test prediction probability:  0.509765625
# 201
# Ground Truth:  0
# Test prediction probability:  0.52001953125
# 202
# Ground Truth:  0
# Test prediction probability:  0.5068359375
# 205
# Ground Truth:  1
# Test prediction probability:  0.464111328125
# 208
# Ground Truth:  1
# Test prediction probability:  0.480224609375
# 209
# Ground Truth:  0
# Test prediction probability:  0.54345703125
# 214
# Ground Truth:  0
# Test prediction probability:  0.54345703125
# 217
# Ground Truth:  0
# Test prediction probability:  0.52099609375
# 222
# Ground Truth:  0
# Test prediction probability:  0.5498046875
# 223
# Ground Truth:  0
# Test prediction probability:  0.56005859375
# 225
# Ground Truth:  0
# Test prediction probability:  0.5625
# 234
# Ground Truth:  0
# Test prediction probability:  0.54736328125
# 235
# Ground Truth:  0
# Test prediction probability:  0.52587890625
# 237
# Ground Truth:  0
# Test prediction probability:  0.5595703125
# 238
# Ground Truth:  0
# Test prediction probability:  0.55810546875
# 239
# Ground Truth:  1
# Test prediction probability:  0.4228515625
# 241
# Ground Truth:  1
# Test prediction probability:  0.285400390625
# 243
# Ground Truth:  1
# Test prediction probability:  0.427978515625
# 245
# Ground Truth:  1
# Test prediction probability:  0.411376953125
# 249
# Ground Truth:  1
# Test prediction probability:  0.439697265625
# 252
# Ground Truth:  1
# Test prediction probability:  0.4423828125
# 253
# Ground Truth:  1
# Test prediction probability:  0.42626953125
# 254
# Ground Truth:  0
# Test prediction probability:  0.51708984375
# 255
# Ground Truth:  1
# Test prediction probability:  0.468505859375
# 257
# Ground Truth:  1
# Test prediction probability:  0.40185546875
# 258
# Ground Truth:  1
# Test prediction probability:  0.40185546875
# 259
# Ground Truth:  1
# Test prediction probability:  0.40185546875
# 260
# Ground Truth:  1
# Test prediction probability:  0.4423828125
# 261
# Ground Truth:  1
# Test prediction probability:  0.392578125
# 263
# Ground Truth:  1
# Test prediction probability:  0.479248046875
# 264
# Ground Truth:  1
# Test prediction probability:  0.4033203125
# 265
# Ground Truth:  1
# Test prediction probability:  0.37060546875
# 267
# Ground Truth:  1
# Test prediction probability:  0.312255859375
# 268
# Ground Truth:  1
# Test prediction probability:  0.4296875
# 269
# Ground Truth:  1
# Test prediction probability:  0.4423828125
# 271
# Ground Truth:  0
# Test prediction probability:  0.501953125
# 273
# Ground Truth:  1
# Test prediction probability:  0.468505859375
# 274
# Ground Truth:  1
# Test prediction probability:  0.439697265625
# 275
# Ground Truth:  1
# Test prediction probability:  0.41162109375
# 276
# Ground Truth:  1
# Test prediction probability:  0.358154296875
# 278
# Ground Truth:  1
# Test prediction probability:  0.431396484375
# 279
# Ground Truth:  1
# Test prediction probability:  0.0953369140625
# 280
# Ground Truth:  0
# Test prediction probability:  0.51953125
# 282
# Ground Truth:  1
# Test prediction probability:  0.46923828125
# 283
# Ground Truth:  1
# Test prediction probability:  0.43115234375
# 284
# Ground Truth:  1
# Test prediction probability:  0.4423828125
# 285
# Ground Truth:  0
# Test prediction probability:  0.5146484375
# 286
# Ground Truth:  1
# Test prediction probability:  0.436279296875
# 288
# Ground Truth:  1
# Test prediction probability:  0.13134765625
# 289
# Ground Truth:  1
# Test prediction probability:  0.48388671875
# 290
# Ground Truth:  1
# Test prediction probability:  0.48388671875
# 291
# Ground Truth:  1
# Test prediction probability:  0.371337890625
# 292
# Ground Truth:  1
# Test prediction probability:  0.486572265625
# 293
# Ground Truth:  1
# Test prediction probability:  0.4423828125
# 294
# Ground Truth:  1
# Test prediction probability:  0.4423828125
# 295
# Ground Truth:  1
# Test prediction probability:  0.456298828125
# 296
# Ground Truth:  1
# Test prediction probability:  0.4423828125
# 300
# Ground Truth:  1
# Test prediction probability:  0.4228515625
# 302
# Ground Truth:  1
# Test prediction probability:  0.38037109375
# 303
# Ground Truth:  1
# Test prediction probability:  0.468505859375
# 304
# Ground Truth:  1
# Test prediction probability:  0.43017578125
# 305
# Ground Truth:  1
# Test prediction probability:  0.43017578125
# 306
# Ground Truth:  1
# Test prediction probability:  0.4228515625
# 308
# Ground Truth:  1
# Test prediction probability:  0.41015625
# 309
# Ground Truth:  1
# Test prediction probability:  0.492919921875
# 310
# Ground Truth:  1
# Test prediction probability:  0.390380859375
# 311
# Ground Truth:  1
# Test prediction probability:  0.390380859375
# 312
# Ground Truth:  1
# Test prediction probability:  0.42041015625
# 313
# Ground Truth:  1
# Test prediction probability:  0.385498046875
# 314
# Ground Truth:  1
# Test prediction probability:  0.431396484375
# 315
# Ground Truth:  1
# Test prediction probability:  0.43017578125
# 316
# Ground Truth:  1
# Test prediction probability:  0.4423828125
# 317
# Ground Truth:  1
# Test prediction probability:  0.4423828125
# 318
# Ground Truth:  1
# Test prediction probability:  0.480224609375
# 319
# Ground Truth:  1
# Test prediction probability:  0.433837890625
# 320
# Ground Truth:  1
# Test prediction probability:  0.485595703125
# 321
# Ground Truth:  1
# Test prediction probability:  0.4423828125
# 322
# Ground Truth:  1
# Test prediction probability:  0.4423828125
# 323
# Ground Truth:  1
# Test prediction probability:  0.4228515625
# 324
# Ground Truth:  1
# Test prediction probability:  0.4423828125
# 325
# Ground Truth:  1
# Test prediction probability:  0.4228515625
# 326
# Ground Truth:  1
# Test prediction probability:  0.48388671875
# 327
# Ground Truth:  1
# Test prediction probability:  0.412353515625
# 328
# Ground Truth:  1
# Test prediction probability:  0.48388671875
# 330
# Ground Truth:  1
# Test prediction probability:  0.45263671875
# 333
# Ground Truth:  1
# Test prediction probability:  0.432861328125
# 334
# Ground Truth:  1
# Test prediction probability:  0.461181640625
# 335
# Ground Truth:  1
# Test prediction probability:  0.452880859375
# 336
# Ground Truth:  1
# Test prediction probability:  0.30078125
# 338
# Ground Truth:  1
# Test prediction probability:  0.409912109375
# 341
# Ground Truth:  1
# Test prediction probability:  0.4228515625
# 343
# Ground Truth:  1
# Test prediction probability:  0.41162109375
# 344
# Ground Truth:  1
# Test prediction probability:  0.45361328125
# 345
# Ground Truth:  1
# Test prediction probability:  0.433837890625
# 346
# Ground Truth:  1
# Test prediction probability:  0.369873046875
# 354
# Ground Truth:  0
# Test prediction probability:  0.509765625
# 355
# Ground Truth:  0
# Test prediction probability:  0.54150390625
# 356
# Ground Truth:  0
# Test prediction probability:  0.5361328125
# 358
# Ground Truth:  0
# Test prediction probability:  0.5029296875
# 362
# Ground Truth:  0
# Test prediction probability:  0.51171875
# 363
# Ground Truth:  0
# Test prediction probability:  0.533203125
# 365
# Ground Truth:  0
# Test prediction probability:  0.5400390625
# 368
# Ground Truth:  0
# Test prediction probability:  0.50341796875
# 369
# Ground Truth:  0
# Test prediction probability:  0.5302734375
# 370
# Ground Truth:  0
# Test prediction probability:  0.5126953125
# 372
# Ground Truth:  0
# Test prediction probability:  0.50146484375
# 378
# Ground Truth:  0
# Test prediction probability:  0.53076171875
# 381
# Ground Truth:  0
# Test prediction probability:  0.5
# 384
# Ground Truth:  0
# Test prediction probability:  0.5244140625
# 386
# Ground Truth:  0
# Test prediction probability:  0.517578125
# 391
# Ground Truth:  0
# Test prediction probability:  0.5703125
# 402
# Ground Truth:  0
# Test prediction probability:  0.56396484375
# 404
# Ground Truth:  1
# Test prediction probability:  0.35498046875
# 406
# Ground Truth:  0
# Test prediction probability:  0.57421875
# 407
# Ground Truth:  0
# Test prediction probability:  0.52587890625
# 408
# Ground Truth:  0
# Test prediction probability:  0.58154296875
# 409
# Ground Truth:  0
# Test prediction probability:  0.5322265625
# 412
# Ground Truth:  0
# Test prediction probability:  0.56005859375
# 413
# Ground Truth:  0
# Test prediction probability:  0.5380859375
# 414
# Ground Truth:  0
# Test prediction probability:  0.568359375
# 415
# Ground Truth:  0
# Test prediction probability:  0.568359375
# 416
# Ground Truth:  0
# Test prediction probability:  0.5224609375
# 418
# Ground Truth:  0
# Test prediction probability:  0.53369140625
# 419
# Ground Truth:  0
# Test prediction probability:  0.5576171875
# 421
# Ground Truth:  1
# Test prediction probability:  0.31689453125
# 422
# Ground Truth:  0
# Test prediction probability:  0.505859375
# 423
# Ground Truth:  0
# Test prediction probability:  0.556640625
# 424
# Ground Truth:  0
# Test prediction probability:  0.56005859375
# 425
# Ground Truth:  0
# Test prediction probability:  0.5732421875
# 426
# Ground Truth:  0
# Test prediction probability:  0.55078125
# 430
# Ground Truth:  0
# Test prediction probability:  0.5244140625
# 432
# Ground Truth:  0
# Test prediction probability:  0.53564453125
# 433
# Ground Truth:  0
# Test prediction probability:  0.51123046875
# 434
# Ground Truth:  0
# Test prediction probability:  0.5244140625
# 436
# Ground Truth:  1
# Test prediction probability:  0.40185546875
# 439
# Ground Truth:  1
# Test prediction probability:  0.4931640625
# 441
# Ground Truth:  1
# Test prediction probability:  0.45458984375
# 445
# Ground Truth:  0
# Test prediction probability:  0.529296875
# 447
# Ground Truth:  1
# Test prediction probability:  0.49951171875
# 449
# Ground Truth:  0
# Test prediction probability:  0.51953125
# 450
# Ground Truth:  1
# Test prediction probability:  0.415283203125
# 451
# Ground Truth:  0
# Test prediction probability:  0.5244140625
# 452
# Ground Truth:  0
# Test prediction probability:  0.505859375
# 456
# Ground Truth:  1
# Test prediction probability:  0.357666015625
# 459
# Ground Truth:  1
# Test prediction probability:  0.49560546875
# 460
# Ground Truth:  0
# Test prediction probability:  0.52490234375
# 463
# Ground Truth:  1
# Test prediction probability:  0.492431640625
# 464
# Ground Truth:  0
# Test prediction probability:  0.52294921875
# 470
# Ground Truth:  1
# Test prediction probability:  0.484375
# 476
# Ground Truth:  1
# Test prediction probability:  0.4482421875
# 480
# Ground Truth:  0
# Test prediction probability:  0.51416015625
# 482
# Ground Truth:  1
# Test prediction probability:  0.49560546875
# 483
# Ground Truth:  0
# Test prediction probability:  0.5146484375
# 487
# Ground Truth:  1
# Test prediction probability:  0.493896484375
# 488
# Ground Truth:  1
# Test prediction probability:  0.47412109375
# 496
# Ground Truth:  0
# Test prediction probability:  0.54443359375
# 498
# Ground Truth:  1
# Test prediction probability:  0.490234375
# 499
# Ground Truth:  1
# Test prediction probability:  0.3798828125
# 500
# Ground Truth:  0
# Test prediction probability:  0.525390625
# 504
# Ground Truth:  0
# Test prediction probability:  0.501953125
# 505
# Ground Truth:  1
# Test prediction probability:  0.4775390625
# 508
# Ground Truth:  0
# Test prediction probability:  0.51123046875
# 509
# Ground Truth:  1
# Test prediction probability:  0.429931640625
# 513
# Ground Truth:  1
# Test prediction probability:  0.473876953125
# 518
# Ground Truth:  1
# Test prediction probability:  0.450439453125
# 520
# Ground Truth:  0
# Test prediction probability:  0.53271484375
# 522
# Ground Truth:  0
# Test prediction probability:  0.51611328125
# 526
# Ground Truth:  1
# Test prediction probability:  0.4931640625
# 527
# Ground Truth:  0
# Test prediction probability:  0.5380859375
# 530
# Ground Truth:  1
# Test prediction probability:  0.47021484375
# 532
# Ground Truth:  0
# Test prediction probability:  0.51611328125
# 533
# Ground Truth:  0
# Test prediction probability:  0.544921875
# 534
# Ground Truth:  0
# Test prediction probability:  0.572265625
# 535
# Ground Truth:  0
# Test prediction probability:  0.5537109375
# 538
# Ground Truth:  0
# Test prediction probability:  0.57958984375
# 540
# Ground Truth:  0
# Test prediction probability:  0.58251953125
# 544
# Ground Truth:  0
# Test prediction probability:  0.583984375
# 545
# Ground Truth:  0
# Test prediction probability:  0.5732421875
# 548
# Ground Truth:  0
# Test prediction probability:  0.58935546875
# 553
# Ground Truth:  0
# Test prediction probability:  0.5712890625
# 555
# Ground Truth:  0
# Test prediction probability:  0.5927734375
# 556
# Ground Truth:  0
# Test prediction probability:  0.5078125
# 558
# Ground Truth:  0
# Test prediction probability:  0.58837890625
# 559
# Ground Truth:  0
# Test prediction probability:  0.5908203125
# 560
# Ground Truth:  0
# Test prediction probability:  0.5556640625
# 561
# Ground Truth:  0
# Test prediction probability:  0.5771484375
# 562
# Ground Truth:  0
# Test prediction probability:  0.58935546875
# 564
# Ground Truth:  0
# Test prediction probability:  0.5927734375
# 565
# Ground Truth:  0
# Test prediction probability:  0.591796875
# 568
# Ground Truth:  0
# Test prediction probability:  0.576171875
# 569
# Ground Truth:  0
# Test prediction probability:  0.5927734375
# 570
# Ground Truth:  0
# Test prediction probability:  0.5947265625
# 571
# Ground Truth:  0
# Test prediction probability:  0.57958984375
# 574
# Ground Truth:  1
# Test prediction probability:  0.353759765625
# 575
# Ground Truth:  1
# Test prediction probability:  0.334228515625
# 580
# Ground Truth:  1
# Test prediction probability:  0.42919921875
# 581
# Ground Truth:  0
# Test prediction probability:  0.52294921875
# 583
# Ground Truth:  0
# Test prediction probability:  0.5107421875
# 585
# Ground Truth:  1
# Test prediction probability:  0.338134765625
# 592
# Ground Truth:  1
# Test prediction probability:  0.465087890625
# 593
# Ground Truth:  1
# Test prediction probability:  0.1663818359375
# 597
# Ground Truth:  1
# Test prediction probability:  0.330322265625
# 599
# Ground Truth:  1
# Test prediction probability:  0.498779296875
# 601
# Ground Truth:  1
# Test prediction probability:  0.498779296875
# 602
# Ground Truth:  0
# Test prediction probability:  0.51708984375
# 607
# Ground Truth:  0
# Test prediction probability:  0.5263671875
# 608
# Ground Truth:  0
# Test prediction probability:  0.505859375
# 613
# Ground Truth:  0
# Test prediction probability:  0.517578125
# 614
# Ground Truth:  0
# Test prediction probability:  0.53515625
# 615
# Ground Truth:  0
# Test prediction probability:  0.55615234375
# 616
# Ground Truth:  0
# Test prediction probability:  0.52685546875
# 617
# Ground Truth:  0
# Test prediction probability:  0.52880859375
# 621
# Ground Truth:  0
# Test prediction probability:  0.5244140625
# 624
# Ground Truth:  0
# Test prediction probability:  0.50927734375
# 625
# Ground Truth:  0
# Test prediction probability:  0.54296875
# 626
# Ground Truth:  0
# Test prediction probability:  0.54541015625
# 627
# Ground Truth:  0
# Test prediction probability:  0.548828125
# 629
# Ground Truth:  0
# Test prediction probability:  0.53515625
# 630
# Ground Truth:  0
# Test prediction probability:  0.537109375
# 632
# Ground Truth:  0
# Test prediction probability:  0.5107421875
# 633
# Ground Truth:  0
# Test prediction probability:  0.5380859375
# 634
# Ground Truth:  0
# Test prediction probability:  0.50830078125
# 636
# Ground Truth:  0
# Test prediction probability:  0.537109375
# 637
# Ground Truth:  0
# Test prediction probability:  0.53173828125
# 638
# Ground Truth:  0
# Test prediction probability:  0.52880859375
# 639
# Ground Truth:  0
# Test prediction probability:  0.53125
# 640
# Ground Truth:  0
# Test prediction probability:  0.53515625
# 641
# Ground Truth:  0
# Test prediction probability:  0.52197265625
# 645
# Ground Truth:  0
# Test prediction probability:  0.53759765625
# 646
# Ground Truth:  0
# Test prediction probability:  0.54052734375
# 647
# Ground Truth:  0
# Test prediction probability:  0.50634765625
# 648
# Ground Truth:  0
# Test prediction probability:  0.5146484375
# 649
# Ground Truth:  0
# Test prediction probability:  0.53173828125
# 651
# Ground Truth:  0
# Test prediction probability:  0.5283203125
# 654
# Ground Truth:  0
# Test prediction probability:  0.53125
# 656
# Ground Truth:  0
# Test prediction probability:  0.5
# 657
# Ground Truth:  0
# Test prediction probability:  0.544921875
# 661
# Ground Truth:  0
# Test prediction probability:  0.51171875
# 662
# Ground Truth:  0
# Test prediction probability:  0.5517578125
# 664
# Ground Truth:  0
# Test prediction probability:  0.56103515625
# 670
# Ground Truth:  0
# Test prediction probability:  0.52783203125
# 673
# Ground Truth:  0
# Test prediction probability:  0.560546875
# 674
# Ground Truth:  1
# Test prediction probability:  0.48779296875
# 678
# Ground Truth:  0
# Test prediction probability:  0.5400390625
# 680
# Ground Truth:  0
# Test prediction probability:  0.53466796875
# 689
# Ground Truth:  0
# Test prediction probability:  0.55322265625
# 692
# Ground Truth:  0
# Test prediction probability:  0.52783203125
# 693
# Ground Truth:  0
# Test prediction probability:  0.55615234375
# 694
# Ground Truth:  0
# Test prediction probability:  0.51220703125
# 698
# Ground Truth:  0
# Test prediction probability:  0.5166015625
# 700
# Ground Truth:  0
# Test prediction probability:  0.560546875
# 701
# Ground Truth:  0
# Test prediction probability:  0.52490234375
# 702
# Ground Truth:  0
# Test prediction probability:  0.56103515625
# 703
# Ground Truth:  0
# Test prediction probability:  0.56201171875
# 704
# Ground Truth:  0
# Test prediction probability:  0.54833984375
# 706
# Ground Truth:  0
# Test prediction probability:  0.5537109375
# 708
# Ground Truth:  0
# Test prediction probability:  0.52734375
# 709
# Ground Truth:  0
# Test prediction probability:  0.52783203125
# 713
# Ground Truth:  0
# Test prediction probability:  0.53369140625
# 715
# Ground Truth:  0
# Test prediction probability:  0.56640625
# 717
# Ground Truth:  0
# Test prediction probability:  0.5556640625
# 719
# Ground Truth:  0
# Test prediction probability:  0.55810546875
# 720
# Ground Truth:  0
# Test prediction probability:  0.54345703125
# 723
# Ground Truth:  0
# Test prediction probability:  0.509765625
# 725
# Ground Truth:  0
# Test prediction probability:  0.568359375
# 726
# Ground Truth:  0
# Test prediction probability:  0.52587890625
# 727
# Ground Truth:  0
# Test prediction probability:  0.55029296875
# 729
# Ground Truth:  0
# Test prediction probability:  0.537109375
# 730
# Ground Truth:  0
# Test prediction probability:  0.51416015625
# 731
# Ground Truth:  0
# Test prediction probability:  0.56982421875
# 732
# Ground Truth:  0
# Test prediction probability:  0.5458984375

# %%
### BERT

# n = 406  #false positive
# n = 555
# n = 559
# n = 570
# n = 140
# n = 149
# n = 223
# n =424
# n = 425
n = 534

# n = 291  # false negative
# n = 336
# n = 575
# n = 593
# n = 421
# n = 404
# n = 279
# n = 267
# n = 241

print(test_data[n]['question'])
print(test_data[n]['score'])
print(df_test['label'].loc[n])
print(probs_test[n])
print(df_test['sentence1'].loc[n])
print(df_test['sentence2'].loc[n])
# Out:
# What is the evidence in this experiment that OJ1 or OJ2 had more acid?
# incorrect
# 0
# 0.572265625
# The syringe for OJ1 rose higher because OJ1 produced more gas, so OJ1 has more acid than OJ2.
# The evidence is that OJ1 has a higher dot.

# %%
# Result -----

# bert_model = "bert-base-uncased" 
# freeze_bert = False 
# maxlen = 128 
# bs = 20
# iters_to_accumulate = 2 
# lr = 5e-4  
# epochs = 6
# test dataset: Unseen questions
# accuracy = 0.6125
# f1 = 0.413

# Result -----

# bert_model = "bert-base-uncased" 
# freeze_bert = False 
# maxlen = 128 
# bs = 20
# iters_to_accumulate = 2 
# lr = 5e-4  
# epochs = 10
# test dataset: Unseen questions
# accuracy = 0.592
# f1 = 0.4432


# bert_model = "bert-base-uncased" 
# freeze_bert = True 
# maxlen = 128 
# bs = 20
# iters_to_accumulate = 2 
# lr = 5e-4  
# epochs = 10
# test dataset: Unseen questions
# accuracy = 0.585
# f1 = 0.4411

# bert_model = "allenai/scibert_scivocab_uncased" 
# freeze_bert = True
# maxlen = 128 
# bs = 20
# iters_to_accumulate = 2 
# lr = 5e-4  
# epochs = 6
# test dataset: Unseen questions
# accuracy = 0.618
# f1 = 0.4696
