# %% [markdown]
# # Project Dataset Loading

# %%
# Clone the dataset repository from github
# !git clone https://github.com/CodyRichter/Automatic-Short-Answer-Grading
# Out:
# Cloning into 'Automatic-Short-Answer-Grading'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 33 (delta 12), reused 23 (delta 8), pack-reused 0
# Unpacking objects: 100% (33/33), done.

# %%
import json

with open('/content/Automatic-Short-Answer-Grading/dataset/train.json', 'r') as tf:
  training_data = json.load(tf)

with open('/content/Automatic-Short-Answer-Grading/dataset/test-unseen-answers.json', 'r') as tf:
  test_unseen_answer_data = json.load(tf)

with open('/content/Automatic-Short-Answer-Grading/dataset/test-unseen-questions.json', 'r') as tf:
  test_unseen_question_data = json.load(tf)

with open('/content/Automatic-Short-Answer-Grading/dataset/test-unseen-domains.json', 'r') as tf:
  test_unseen_domain_data = json.load(tf)

print('Number of Training + Validation Data Responses', len(training_data))
# Out:
# Number of Training + Validation Data Responses 16265

# %%
from torch.utils.data import Dataset, DataLoader

class ShortAnswerGradingDataset(Dataset):
    def __init__(self, dataset):
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        # Note: I handle the parsing in the data loading from XML section
        # Returns a dict for each item with the following keys: 'question', 'ref', 'response', 'score' all of type 'str'
        return self.dataset[idx]

# %% [markdown]
# ## Dataset Train/Validation/Test Splits
#
# This step is very important, and requires extra logic due to the nature of the dataset. The train dataset can contain augmented items, but the validation dataset cannot. Additionally, the validation dataset must not contain un-augmented items while the original dataset contains backtranslated versions of the same response, as this is essentially "cheating" due to the similarity between the backtranslated response and the original one. Therefore, we have to do this extra logic on the training and validation sets to make sure that the validation set is a fair measurement of the dataset.
#
# Note that there are some unknown questions in the validation set that are not in the training set, however all of the questions are in the same domain. This means that this validation set is most similar to the test set with unseen answers but known questions, but with a few questions that may not have been seen by the training set.

# %%
training_dataset = ShortAnswerGradingDataset(training_data)
test_dataset_unseen_answers = ShortAnswerGradingDataset(test_unseen_answer_data)
test_dataset_unseen_questions = ShortAnswerGradingDataset(test_unseen_question_data)
test_dataset_unseen_domains = ShortAnswerGradingDataset(test_unseen_domain_data)

from sklearn.model_selection import train_test_split

training_dataset, validation_dataset = train_test_split(training_dataset, test_size=0.1, random_state=0)

validation_parent_ids = set()
validation_ids_to_remove = set()
validation_original_ids = set()

# Step 1: Get IDs of Original Responses and mark augmented ones for deletion
for validation_item in validation_dataset:
  if validation_item['aug']:
    validation_parent_ids.add(validation_item['aug_metadata']['parent_id'])
    validation_ids_to_remove.add(validation_item['id'])
  else:
    validation_original_ids.add(validation_item['id'])

train_ids_to_remove = set()

# Step 2: Obtain Original Respones for validation set and mark augmented
#         dataset items for removal if the original is in the validation set
for train_item in training_dataset:

  # If the original is in the validation set, remove from the training set
  if train_item['aug'] and train_item['aug_metadata']['parent_id'] in validation_original_ids:
    train_ids_to_remove.add(train_item['id'])

  # If the original is in the training set, add it to the validation set
  # and then mark it for deletion from the training set
  if not train_item['aug'] and train_item['id'] in validation_parent_ids:
    validation_dataset.append(train_item)
    train_ids_to_remove.add(train_item['id'])

# Step 3: Perform removal operations
validation_dataset[:] = [x for x in validation_dataset if x['id'] not in validation_ids_to_remove]
training_dataset[:] = [x for x in training_dataset if x['id'] not in train_ids_to_remove]

# %%
print('Number of Training Samples', len(training_dataset))
print('Number of Validation Samples', len(validation_dataset))
print('Number of Test Data (New Answer) Responses', len(test_unseen_answer_data))
print('Number of Test Data (New Question) Responses', len(test_unseen_question_data))
print('Number of Test Data (New Domain) Responses', len(test_unseen_domain_data))
# Out:
# Number of Training Samples 12805
# Number of Validation Samples 1380
# Number of Test Data (New Answer) Responses 540
# Number of Test Data (New Question) Responses 733
# Number of Test Data (New Domain) Responses 4562

# %% [markdown]
# ## Viewing Samples in Dataset

# %%
for idx, training_item in enumerate(training_dataset):
  print(training_item)
  if idx == 10:
    break
# Out:
# {'question': "Pam and her family were planning a hike. Pam found 2 maps of the same area. Her friend recommended she use the topographic map when they went to the lake. Why would Pam's friend recommend using the topographic map for the hike?", 'ref': 'She recommended the topographic map because the map shows the elevations along the trail. Pam would know where the trail was the steepest.', 'response': 'Because both maps show the shapes of landforms, but a topographic map shows elevation and dip.', 'score': 'incorrect', 'aug': True, 'id': 18221, 'aug_metadata': {'parent_id': 3816, 'translation_seq': ['en', 'es', 'en']}}
# {'question': 'When a seed germinates, why does the root grow first?', 'ref': 'The root grows first so the root can take up water for the plant.', 'response': 'Because they need roots to produce leaves.', 'score': 'incorrect', 'aug': True, 'id': 15990, 'aug_metadata': {'parent_id': 3117, 'translation_seq': ['en', 'es', 'en']}}
# {'question': 'Salt crystals form when the water evaporates from saltwater. Describe the salt crystals.', 'ref': 'The salt crystals are squares with Xs on top.', 'response': "It's a square with little Xs on it.", 'score': 'correct', 'aug': True, 'id': 20558, 'aug_metadata': {'parent_id': 4518, 'translation_seq': ['en', 'es', 'fr', 'de', 'en']}}
# {'question': 'Look at the picture below [which shows a balance tipped down on the side containing a ball; the right cup has 20 grams and 10 grams mass pieces]. The mass of the ball is one of the following. It must be A. 20 grams. B. 30 grams. (C. 40 grams.) Explain why you chose the answer that you did.', 'ref': 'There is 30 grams (20 grams plus 10 grams) in the right cup. The balance is tipped down on the ball side which means the ball weighs more than 30 grams. 40 grams is the only weight heavier than 30 grams.', 'response': 'Because 20 grams plus 10 grams is 30 grams.', 'score': 'incorrect', 'aug': True, 'id': 18307, 'aug_metadata': {'parent_id': 3843, 'translation_seq': ['en', 'es', 'en']}}
# {'question': "Grace set up a science experiment. Here's what she wrote in her notebook. First I put eggshells into a cup and covered them with vinegar. After a while, small bubbles appeared on the surface of the eggshells. The next day there were more bubbles. In a couple of days, the eggshells were gone and the liquid was clear. I think I made a solution and a reaction. Explain why Grace thinks she made a solution.", 'ref': 'A solution was created when the eggshells disappeared (dissolved) and the mixture ended up as a clear liquid.', 'response': 'I think Grace thinks she found a solution by mixing eggshells and vinegar.', 'score': 'incorrect', 'aug': True, 'id': 11444, 'aug_metadata': {'parent_id': 1698, 'translation_seq': ['en', 'es', 'fr', 'de', 'en']}}
# {'question': 'Describe how you can tell the difference between the crystals from the calcite test and salt crystals when you observe them in an evaporation dish.', 'ref': 'The crystals have different shapes. Salt crystals are square with little Xs. The calcite crystals are shaped like needles (long and skinny).', 'response': 'Because the calcite test crystals were long and thin. The salt crystals were thick and textured.', 'score': 'correct', 'aug': True, 'id': 12196, 'aug_metadata': {'parent_id': 1951, 'translation_seq': ['en', 'es', 'fr', 'de', 'en']}}
# {'question': 'Mark an X next to each of the following that can cause more erosion in a streamtable experiment. (Use a water source with a bigger hole.) Use a water source with a smaller hole.  Make the slope flatter. (Make the slope steeper.) Explain why your choices cause more erosion.', 'ref': 'A bigger hole puts more water in the stream. Increased flow moves more earth materials, increasing erosion. A steeper slope makes the water flow faster. Faster flow moves more earth materials, increasing erosion.', 'response': "Because we didn't experiment that way and it worked, it did the same thing we achieved.", 'score': 'incorrect', 'aug': True, 'id': 21771, 'aug_metadata': {'parent_id': 4876, 'translation_seq': ['en', 'es', 'fr', 'de', 'en']}}
# {'question': 'Jim used a solid and water to make Mixtures one (one spoon of solid in 100 milliliters water was clear with nothing on the bottom), 3 (3 spoons of solid in 100 milliliters water was clear with nothing on the bottom), 4 (4 spoons of solid in 100 milliliters water was clear with material on the bottom), and 5 (5 spoons of solid in 100 milliliters water was clear with material on the bottom) as shown below. He stirred each one and observed the results. Describe how Jim could separate the dissolved solid from the water in Mixture one. What happens to the solid and to the water?', 'ref': 'Set up evaporation dishes. The water will go into the air (evaporate) and the solid will be left in the dish (crystallize).', 'response': 'Pour the solution into evaporating dishes. The water evaporates, or turns into a gas, and the solid crystallizes.', 'score': 'correct', 'aug': False, 'id': 227}
# {'question': 'Why does a rubber band make a sound when you pluck it (pull and let go quickly)?', 'ref': 'The rubber band vibrates.', 'response': 'Starting is pulling.', 'score': 'incorrect', 'aug': True, 'id': 21354, 'aug_metadata': {'parent_id': 4726, 'translation_seq': ['en', 'es', 'en']}}
# {'question': 'Explain in one sentence what each graph tells you. Graph A) number of tree rings versus time.', 'ref': 'As time increases, the number of tree rings also increases.', 'response': 'Annual rings and annual rings are multiplying.', 'score': 'incorrect', 'aug': True, 'id': 11580, 'aug_metadata': {'parent_id': 1744, 'translation_seq': ['en', 'es', 'fr', 'de', 'cs', 'en']}}
# {'question': 'A solution of water and material A is clear. A solution of water and material B is also clear. When the 2 solutions are mixed, a white solid settles to the bottom, leaving a clear liquid. What does the white solid indicate?', 'ref': 'A chemical reaction occurred. [The white solid is a precipitate (a new material) which indicates the reaction.]', 'response': "Which is a knockdown, because when they mix materials together and there's a cherry and there's a new material, then it's a knockdown.", 'score': 'incorrect', 'aug': True, 'id': 14588, 'aug_metadata': {'parent_id': 2712, 'translation_seq': ['en', 'es', 'fr', 'de', 'en']}}

# %%
for idx, val_item in enumerate(validation_dataset):
  print(val_item)
  if idx == 10:
    break
# Out:
# {'question': 'Denise made a circuit to light a bulb or run a motor off a D-cell battery. She used a special switch. Below is the schematic diagram of her circuit. The switch is inside the dotted box. Why will the bulb light when she moves the switch to the left?', 'ref': 'There is a complete circuit connecting the bulb to the D-cell battery.', 'response': 'I learned it in class.', 'score': 'incorrect', 'aug': False, 'id': 4645}
# {'question': 'Jim used a solid and water to make Mixtures one (one spoon of solid in 100 milliliters water was clear with nothing on the bottom), 3 (3 spoons of solid in 100 milliliters water was clear with nothing on the bottom), 4 (4 spoons of solid in 100 milliliters water was clear with material on the bottom), and 5 (5 spoons of solid in 100 milliliters water was clear with material on the bottom) as shown below. He stirred each one and observed the results. If Jim made Mixture 2 with 2 spoons of solid in 100 milliliters of water, what would he observe? What evidence do you have to support this?', 'ref': 'Jim would see a clear solution. 3 spoons of solid dissolves, so 2 spoons will dissolve.', 'response': '2 spoons of solid and 100 milliliters of water and it was clear material on the bottom.', 'score': 'incorrect', 'aug': False, 'id': 4711}
# {'question': 'Bryan taped a golf tee to a globe of the Earth. He shined a flashlight on the globe. The best way for Bryan to demonstrate how shadows change during the day would be to: (rotate the globe.) move the flashlight. Why would this best demonstrate how shadows change during the day?', 'ref': 'Shadows change during the day because the Earth is turning. The Sun stays in one place.', 'response': 'Because it rotates around the sun.', 'score': 'incorrect', 'aug': False, 'id': 1253}
# {'question': 'Why does a rubber band make a sound when you pluck it (pull and let go quickly)?', 'ref': 'The rubber band vibrates.', 'response': 'Because the rubber band is vibrating.', 'score': 'correct', 'aug': False, 'id': 4770}
# {'question': 'Describe the relationship between the length of the string and the number of swings a swinger makes in 15 seconds.', 'ref': 'The shorter the string is, the more the string swings in 15 seconds.  The longer the string is, the less the string swings in 15 seconds.', 'response': 'It changes the number of the swing.', 'score': 'incorrect', 'aug': False, 'id': 4007}
# {'question': 'What is your "rule" for deciding if the part of a plant you are observing is a fruit?', 'ref': 'If a part of the plant contains seeds, that part is the fruit.', 'response': 'If has seed, in it the do have seeds, in it.', 'score': 'correct', 'aug': False, 'id': 4446}
# {'question': 'Why does a rubber band make a sound when you pluck it (pull and let go quickly)?', 'ref': 'The rubber band vibrates.', 'response': 'Low.', 'score': 'incorrect', 'aug': False, 'id': 4760}
# {'question': 'Janet found the solubility of silver chloride to be 86 grams in 50 milliliters of water. Mike found the solubility of silver nitrate to be 108 grams in 50 milliliters of water. Janet and Mike thought they must have made a mistake. They thought the solubilities of all materials in water should be the same. Is it possible that both solubilities are correct? Explain your answer.', 'ref': 'Yes, they could both be correct. Solubility is not the same for all materials.', 'response': 'Yes because the water has different materials in it and the materials have different atoms and stuff and that makes changes to what happens to them in water and their solubility.', 'score': 'correct', 'aug': False, 'id': 253}
# {'question': 'The inside of a pea seed is shown below. Describe the function of each of the parts: embryo.', 'ref': 'The embryo contains the tiny leaves and root of the plant.', 'response': 'The baby plant.', 'score': 'correct', 'aug': False, 'id': 1817}
# {'question': "Anna wants to compare the fat in walnuts and peanuts, but she isn't sure how. Write a procedure Anna can use to compare the fat in walnuts and peanuts.", 'ref': 'Measure out equal masses of walnuts and peanuts. Smash the samples uniformly in the same size area on brown paper. Wait the same time for each sample.', 'response': 'First you get the food. Then you get brown paper or some type of paper. Next you squish the peanuts and walnuts on 2 pieces of paper. Finally you wait 3 days before checking the grease marks.', 'score': 'incorrect', 'aug': False, 'id': 3948}
# {'question': 'Describe the relationship between the length of the string and the number of swings a swinger makes in 15 seconds.', 'ref': 'The shorter the string is, the more the string swings in 15 seconds.  The longer the string is, the less the string swings in 15 seconds.', 'response': 'The longer the pendulum it will not swing that much.', 'score': 'correct', 'aug': False, 'id': 3984}

# %%
for idx, test_item in enumerate(test_dataset_unseen_answers):
  print(test_item)
  if idx == 10:
    break
# Out:
# {'question': 'The sand and flour in the gray material from mock rocks is separated by mixing with water and allowing the mixture to settle. Explain why the sand and flour separate.', 'ref': 'The sand particles are larger and settle first. The flour particles are smaller and therefore settle more slowly.', 'response': 'Because it will not get dry.', 'score': 'incorrect', 'aug': False, 'id': 4969}
# {'question': 'The sand and flour in the gray material from mock rocks is separated by mixing with water and allowing the mixture to settle. Explain why the sand and flour separate.', 'ref': 'The sand particles are larger and settle first. The flour particles are smaller and therefore settle more slowly.', 'response': 'Because one is heavy and one is not.', 'score': 'incorrect', 'aug': False, 'id': 4970}
# {'question': 'The sand and flour in the gray material from mock rocks is separated by mixing with water and allowing the mixture to settle. Explain why the sand and flour separate.', 'ref': 'The sand particles are larger and settle first. The flour particles are smaller and therefore settle more slowly.', 'response': 'Because sand and flour do not mix very well.', 'score': 'incorrect', 'aug': False, 'id': 4971}
# {'question': 'The sand and flour in the gray material from mock rocks is separated by mixing with water and allowing the mixture to settle. Explain why the sand and flour separate.', 'ref': 'The sand particles are larger and settle first. The flour particles are smaller and therefore settle more slowly.', 'response': 'The rock is tough.', 'score': 'incorrect', 'aug': False, 'id': 4972}
# {'question': 'Andi and Scott decided to investigate solar water heaters using collectors of different colors (but the same size) as one variable and covered versus uncovered as a second variable. Look at the graph of their data and answer the questions below. Why would comparing only the red uncovered heater with the blue covered heater not provide useful information?', 'ref': 'When 2 variables are changed, it is impossible to determine which variable is causing what effect.', 'response': 'Because the red is uncovered and blue is covered and you cannot compare them.', 'score': 'correct', 'aug': False, 'id': 4973}
# {'question': 'Andi and Scott decided to investigate solar water heaters using collectors of different colors (but the same size) as one variable and covered versus uncovered as a second variable. Look at the graph of their data and answer the questions below. Why would comparing only the red uncovered heater with the blue covered heater not provide useful information?', 'ref': 'When 2 variables are changed, it is impossible to determine which variable is causing what effect.', 'response': 'Red uncovered water is not really hot, and the blue covered is hot, so when you compare them you would not get that much of useful information.', 'score': 'correct', 'aug': False, 'id': 4974}
# {'question': 'Andi and Scott decided to investigate solar water heaters using collectors of different colors (but the same size) as one variable and covered versus uncovered as a second variable. Look at the graph of their data and answer the questions below. Why would comparing only the red uncovered heater with the blue covered heater not provide useful information?', 'ref': 'When 2 variables are changed, it is impossible to determine which variable is causing what effect.', 'response': 'Because one is uncovered and one is covered. Also I think because they are now the same color.', 'score': 'incorrect', 'aug': False, 'id': 4975}
# {'question': 'Andi and Scott decided to investigate solar water heaters using collectors of different colors (but the same size) as one variable and covered versus uncovered as a second variable. Look at the graph of their data and answer the questions below. Why would comparing only the red uncovered heater with the blue covered heater not provide useful information?', 'ref': 'When 2 variables are changed, it is impossible to determine which variable is causing what effect.', 'response': 'Because blue goes so high and red goes so low you cannot tell anything.', 'score': 'incorrect', 'aug': False, 'id': 4976}
# {'question': 'Look at the circuit in the picture. The gap between the D-cell and the switch needs to be connected. Can you use a piece of string to make the connection? Why or why not?', 'ref': 'No, string is an insulator, so the pathway would not be completed.', 'response': 'The string does not have iron in it to make it work.', 'score': 'incorrect', 'aug': False, 'id': 4977}
# {'question': 'Look at the circuit in the picture. The gap between the D-cell and the switch needs to be connected. Can you use a piece of string to make the connection? Why or why not?', 'ref': 'No, string is an insulator, so the pathway would not be completed.', 'response': 'Because it is not going in a circle so it will not work.', 'score': 'incorrect', 'aug': False, 'id': 4978}
# {'question': 'Look at the circuit in the picture. The gap between the D-cell and the switch needs to be connected. Can you use a piece of string to make the connection? Why or why not?', 'ref': 'No, string is an insulator, so the pathway would not be completed.', 'response': 'You can use string because it will hook and make it work.', 'score': 'incorrect', 'aug': False, 'id': 4979}

# %%
for idx, test_item in enumerate(test_dataset_unseen_questions):
  print(test_item)
  if idx == 10:
    break
# Out:
# {'question': 'What happens to earth materials during erosion?', 'ref': 'Earth materials are worn away and moved during erosion.', 'response': 'Earth material gets eroded and carried away.', 'score': 'incorrect', 'aug': False, 'id': 5509}
# {'question': 'What happens to earth materials during erosion?', 'ref': 'Earth materials are worn away and moved during erosion.', 'response': 'They are eroded by water, wind, and or ice.', 'score': 'incorrect', 'aug': False, 'id': 5510}
# {'question': 'What happens to earth materials during erosion?', 'ref': 'Earth materials are worn away and moved during erosion.', 'response': 'They form into other solids water, lava, wind.', 'score': 'incorrect', 'aug': False, 'id': 5511}
# {'question': 'What happens to earth materials during erosion?', 'ref': 'Earth materials are worn away and moved during erosion.', 'response': 'They just move around.', 'score': 'incorrect', 'aug': False, 'id': 5512}
# {'question': 'What happens to earth materials during erosion?', 'ref': 'Earth materials are worn away and moved during erosion.', 'response': 'They all settle to the bottom.', 'score': 'incorrect', 'aug': False, 'id': 5513}
# {'question': 'What happens to earth materials during erosion?', 'ref': 'Earth materials are worn away and moved during erosion.', 'response': 'They make canyons and erode away.', 'score': 'incorrect', 'aug': False, 'id': 5514}
# {'question': 'What happens to earth materials during erosion?', 'ref': 'Earth materials are worn away and moved during erosion.', 'response': 'They get carried away by wind, ice, or water.', 'score': 'incorrect', 'aug': False, 'id': 5515}
# {'question': 'What happens to earth materials during erosion?', 'ref': 'Earth materials are worn away and moved during erosion.', 'response': 'During erosion earth materials are worn away by water wind or ice.', 'score': 'incorrect', 'aug': False, 'id': 5516}
# {'question': 'What happens to earth materials during erosion?', 'ref': 'Earth materials are worn away and moved during erosion.', 'response': 'They get eroded away.', 'score': 'incorrect', 'aug': False, 'id': 5517}
# {'question': 'What happens to earth materials during erosion?', 'ref': 'Earth materials are worn away and moved during erosion.', 'response': 'Earth materials start to weather away from wind, water, and ice. When they are being eroded.', 'score': 'incorrect', 'aug': False, 'id': 5518}
# {'question': 'What happens to earth materials during erosion?', 'ref': 'Earth materials are worn away and moved during erosion.', 'response': 'Earth materials are worn away by I see ant other stuff.', 'score': 'incorrect', 'aug': False, 'id': 5519}

# %%
for idx, test_item in enumerate(test_dataset_unseen_domains):
  print(test_item)
  if idx == 10:
    break
# Out:
# {'question': 'Ted poured the same amount of water into 2 small containers, X and Y. He placed them together where they would not be disturbed. After several days, all of the water had evaporated from one of the containers. The other container still had some water. Which container, X or Y, was empty? Explain why the water in that container evaporated more quickly than the water in the other container.', 'ref': 'Container X has more surface area or more water exposed to the air so the water evaporated faster.', 'response': 'Because X had more room to evaporate and Y did not.', 'score': 'correct', 'aug': False, 'id': 6242}
# {'question': 'Ted poured the same amount of water into 2 small containers, X and Y. He placed them together where they would not be disturbed. After several days, all of the water had evaporated from one of the containers. The other container still had some water. Which container, X or Y, was empty? Explain why the water in that container evaporated more quickly than the water in the other container.', 'ref': 'Container X has more surface area or more water exposed to the air so the water evaporated faster.', 'response': 'The water in container X had a more open space to evaporate, so it evaporated. The water in container Y could not evaporate because it did not have an open space to evaporate.', 'score': 'correct', 'aug': False, 'id': 6243}
# {'question': 'Ted poured the same amount of water into 2 small containers, X and Y. He placed them together where they would not be disturbed. After several days, all of the water had evaporated from one of the containers. The other container still had some water. Which container, X or Y, was empty? Explain why the water in that container evaporated more quickly than the water in the other container.', 'ref': 'Container X has more surface area or more water exposed to the air so the water evaporated faster.', 'response': 'X evaporated more than Y because container X has more surface area than container Y so it evaporated faster.', 'score': 'correct', 'aug': False, 'id': 6244}
# {'question': 'Ted poured the same amount of water into 2 small containers, X and Y. He placed them together where they would not be disturbed. After several days, all of the water had evaporated from one of the containers. The other container still had some water. Which container, X or Y, was empty? Explain why the water in that container evaporated more quickly than the water in the other container.', 'ref': 'Container X has more surface area or more water exposed to the air so the water evaporated faster.', 'response': 'There is more surface area on container X so more water could evaporate at one time.', 'score': 'correct', 'aug': False, 'id': 6245}
# {'question': 'Ted poured the same amount of water into 2 small containers, X and Y. He placed them together where they would not be disturbed. After several days, all of the water had evaporated from one of the containers. The other container still had some water. Which container, X or Y, was empty? Explain why the water in that container evaporated more quickly than the water in the other container.', 'ref': 'Container X has more surface area or more water exposed to the air so the water evaporated faster.', 'response': 'The water in X evaporated because the more surface area the more air can get to it to make it evaporate faster.', 'score': 'correct', 'aug': False, 'id': 6246}
# {'question': 'Ted poured the same amount of water into 2 small containers, X and Y. He placed them together where they would not be disturbed. After several days, all of the water had evaporated from one of the containers. The other container still had some water. Which container, X or Y, was empty? Explain why the water in that container evaporated more quickly than the water in the other container.', 'ref': 'Container X has more surface area or more water exposed to the air so the water evaporated faster.', 'response': 'X evaporated faster because it has more space to evaporate quicker.', 'score': 'correct', 'aug': False, 'id': 6247}
# {'question': 'Ted poured the same amount of water into 2 small containers, X and Y. He placed them together where they would not be disturbed. After several days, all of the water had evaporated from one of the containers. The other container still had some water. Which container, X or Y, was empty? Explain why the water in that container evaporated more quickly than the water in the other container.', 'ref': 'Container X has more surface area or more water exposed to the air so the water evaporated faster.', 'response': 'The water in container X evaporated more quickly than the water in container Y because in container X there is more wide and open, so the water evaporated faster, but since the container for cup Y was closed and not open very much, then the water evaporated slower.', 'score': 'correct', 'aug': False, 'id': 6248}
# {'question': 'Ted poured the same amount of water into 2 small containers, X and Y. He placed them together where they would not be disturbed. After several days, all of the water had evaporated from one of the containers. The other container still had some water. Which container, X or Y, was empty? Explain why the water in that container evaporated more quickly than the water in the other container.', 'ref': 'Container X has more surface area or more water exposed to the air so the water evaporated faster.', 'response': 'The water in container X evaporates faster because the container has more surface area.', 'score': 'correct', 'aug': False, 'id': 6249}
# {'question': 'Ted poured the same amount of water into 2 small containers, X and Y. He placed them together where they would not be disturbed. After several days, all of the water had evaporated from one of the containers. The other container still had some water. Which container, X or Y, was empty? Explain why the water in that container evaporated more quickly than the water in the other container.', 'ref': 'Container X has more surface area or more water exposed to the air so the water evaporated faster.', 'response': 'X because X has more surface area and if you have lots of surface area it will evaporate faster.', 'score': 'correct', 'aug': False, 'id': 6250}
# {'question': 'Ted poured the same amount of water into 2 small containers, X and Y. He placed them together where they would not be disturbed. After several days, all of the water had evaporated from one of the containers. The other container still had some water. Which container, X or Y, was empty? Explain why the water in that container evaporated more quickly than the water in the other container.', 'ref': 'Container X has more surface area or more water exposed to the air so the water evaporated faster.', 'response': 'Container X had a bigger surface area, causing the water to evaporate more quickly.', 'score': 'correct', 'aug': False, 'id': 6251}
# {'question': 'Ted poured the same amount of water into 2 small containers, X and Y. He placed them together where they would not be disturbed. After several days, all of the water had evaporated from one of the containers. The other container still had some water. Which container, X or Y, was empty? Explain why the water in that container evaporated more quickly than the water in the other container.', 'ref': 'Container X has more surface area or more water exposed to the air so the water evaporated faster.', 'response': 'The X container has more surface area than the Y container.', 'score': 'correct', 'aug': False, 'id': 6252}
